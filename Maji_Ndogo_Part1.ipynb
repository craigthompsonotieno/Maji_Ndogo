# %% [markdown]
# # Beginning our data-driven journey in Maji Ndogo

# %% [markdown]
# # Establishing a Connection to the MySQL Database

# %%
import json
import pandas as pd
import mysql.connector
from tabulate import tabulate

# Load database credentials from config.json
def load_config():
    with open("config.json", "r") as file:
        return json.load(file)

# Load the configuration
config = load_config()

# Function to create a connection to the MySQL database
def create_connection():
    connection = mysql.connector.connect(
        host=config["DB_HOST"],      
        user=config["DB_USER"],      
        password=config["DB_PASSWORD"],  
        database=config["DB_NAME"]      
    )
    return connection

# Create a connection object
conn = create_connection()

# Check the connection status
if conn.is_connected():
    print("Successfully connected to the database")
else:
    print("Failed to connect to the database")
# Out:
# Successfully connected to the database

# %% [markdown]
# # Get to know the Data

# %% [markdown]
# ## View All Tables Present

# %%
# Function to execute a query and return results as a DataFrame
def execute_query(query):
    conn = create_connection()
    cursor = conn.cursor()
    cursor.execute(query)
    
    # Fetch all results
    results = cursor.fetchall()
    
    # Get column names from cursor description
    column_names = [desc[0] for desc in cursor.description]
    
    # Close cursor and connection
    cursor.close()
    conn.close()
    
    # Create a DataFrame from the fetched results
    df = pd.DataFrame(results, columns=column_names)
    return df

# Function to color headers with a custom style
def color_header():
    return [{'selector': 'thead th', 'props': [('background-color', 'lightblue'),
                                               ('color', 'black'),
                                               ('font-size', '12pt'),
                                               ('text-align', 'center')]}]

# Function to apply cell formatting for individual DataFrame cells
def highlight_cells(val):
    return 'background-color: #f4f4f4'  # Light grey for cell background

# Query to show all tables in the current database
query = "SHOW TABLES;"
tables_df = execute_query(query)

# Rename the column to 'Table Name'
tables_df.columns = ['Table Name']

# Apply custom table styles and display the styled DataFrame
styled_tables_df = (
    tables_df.style
    .applymap(highlight_cells)  # Apply custom function to highlight cells
    .set_table_styles(color_header())  # Apply custom header style
)

# Display the DataFrame with styles
print("Tables in the current database:")
display(styled_tables_df)
# Out:
# Tables in the current database:
# <style type="text/css">
# #T_089c2 thead th {
#   background-color: lightblue;
#   color: black;
#   font-size: 12pt;
#   text-align: center;
# }
# #T_089c2_row0_col0, #T_089c2_row1_col0, #T_089c2_row2_col0, #T_089c2_row3_col0, #T_089c2_row4_col0, #T_089c2_row5_col0, #T_089c2_row6_col0, #T_089c2_row7_col0 {
#   background-color: #f4f4f4;
# }
# </style>
# <table id="T_089c2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_089c2_level0_col0" class="col_heading level0 col0" >Table Name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_089c2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_089c2_row0_col0" class="data row0 col0" >data_dictionary</td>
#     </tr>
#     <tr>
#       <th id="T_089c2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_089c2_row1_col0" class="data row1 col0" >employee</td>
#     </tr>
#     <tr>
#       <th id="T_089c2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_089c2_row2_col0" class="data row2 col0" >global_water_access</td>
#     </tr>
#     <tr>
#       <th id="T_089c2_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_089c2_row3_col0" class="data row3 col0" >location</td>
#     </tr>
#     <tr>
#       <th id="T_089c2_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_089c2_row4_col0" class="data row4 col0" >visits</td>
#     </tr>
#     <tr>
#       <th id="T_089c2_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_089c2_row5_col0" class="data row5 col0" >water_quality</td>
#     </tr>
#     <tr>
#       <th id="T_089c2_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_089c2_row6_col0" class="data row6 col0" >water_source</td>
#     </tr>
#     <tr>
#       <th id="T_089c2_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_089c2_row7_col0" class="data row7 col0" >well_pollution</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Displaying Sample Data from All Tables in the Database

# %%
# Function to color headers with a custom style
def color_header():
    return [{'selector': 'thead th', 'props': [('background-color', 'lightblue'),
                                               ('color', 'black'),
                                               ('font-size', '12pt'),
                                               ('text-align', 'center')]}]

# Function to apply cell formatting for individual DataFrame cells
def highlight_cells(val):
    return 'background-color: #f4f4f4'  # Light grey for cell background

# Get all tables in the database
tables_query = "SHOW TABLES;"
tables_df = execute_query(tables_query)

# Rename the column for better clarity
tables_df.columns = ['Table Name']

# Iterate through each table and display the first 10 rows as a styled DataFrame
for index, row in tables_df.iterrows():
    table_name = row['Table Name']  # Extract the table name from the DataFrame
    print(f"\nFirst 10 rows from table: {table_name}")
    
    # Query to fetch the first 10 rows from the current table
    query = f"SELECT * FROM {table_name} LIMIT 10;"
    
    # Execute the query to fetch the first 10 rows as a DataFrame
    table_df = execute_query(query)
    
    # Apply custom table styles and display the styled DataFrame
    styled_table = (
        table_df.style
        .applymap(highlight_cells)  # Apply custom function to highlight cells
        .set_table_styles(color_header())  # Apply custom header style
    )
    
    # Display the styled table
    display(styled_table)
# Out:
# First 10 rows from table: data_dictionary
# <style type="text/css">
# #T_f576e thead th {
#   background-color: lightblue;
#   color: black;
#   font-size: 12pt;
#   text-align: center;
# }
# #T_f576e_row0_col0, #T_f576e_row0_col1, #T_f576e_row0_col2, #T_f576e_row0_col3, #T_f576e_row0_col4, #T_f576e_row1_col0, #T_f576e_row1_col1, #T_f576e_row1_col2, #T_f576e_row1_col3, #T_f576e_row1_col4, #T_f576e_row2_col0, #T_f576e_row2_col1, #T_f576e_row2_col2, #T_f576e_row2_col3, #T_f576e_row2_col4, #T_f576e_row3_col0, #T_f576e_row3_col1, #T_f576e_row3_col2, #T_f576e_row3_col3, #T_f576e_row3_col4, #T_f576e_row4_col0, #T_f576e_row4_col1, #T_f576e_row4_col2, #T_f576e_row4_col3, #T_f576e_row4_col4, #T_f576e_row5_col0, #T_f576e_row5_col1, #T_f576e_row5_col2, #T_f576e_row5_col3, #T_f576e_row5_col4, #T_f576e_row6_col0, #T_f576e_row6_col1, #T_f576e_row6_col2, #T_f576e_row6_col3, #T_f576e_row6_col4, #T_f576e_row7_col0, #T_f576e_row7_col1, #T_f576e_row7_col2, #T_f576e_row7_col3, #T_f576e_row7_col4, #T_f576e_row8_col0, #T_f576e_row8_col1, #T_f576e_row8_col2, #T_f576e_row8_col3, #T_f576e_row8_col4, #T_f576e_row9_col0, #T_f576e_row9_col1, #T_f576e_row9_col2, #T_f576e_row9_col3, #T_f576e_row9_col4 {
#   background-color: #f4f4f4;
# }
# </style>
# <table id="T_f576e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f576e_level0_col0" class="col_heading level0 col0" >table_name</th>
#       <th id="T_f576e_level0_col1" class="col_heading level0 col1" >column_name</th>
#       <th id="T_f576e_level0_col2" class="col_heading level0 col2" >description</th>
#       <th id="T_f576e_level0_col3" class="col_heading level0 col3" >datatype</th>
#       <th id="T_f576e_level0_col4" class="col_heading level0 col4" >related_to</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f576e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f576e_row0_col0" class="data row0 col0" >employee</td>
#       <td id="T_f576e_row0_col1" class="data row0 col1" >assigned_employee_id</td>
#       <td id="T_f576e_row0_col2" class="data row0 col2" >Unique ID assigned to each employee</td>
#       <td id="T_f576e_row0_col3" class="data row0 col3" >INT</td>
#       <td id="T_f576e_row0_col4" class="data row0 col4" >visits</td>
#     </tr>
#     <tr>
#       <th id="T_f576e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f576e_row1_col0" class="data row1 col0" >employee</td>
#       <td id="T_f576e_row1_col1" class="data row1 col1" >employee_name</td>
#       <td id="T_f576e_row1_col2" class="data row1 col2" >Name of the employee</td>
#       <td id="T_f576e_row1_col3" class="data row1 col3" >VARCHAR(255)</td>
#       <td id="T_f576e_row1_col4" class="data row1 col4" ></td>
#     </tr>
#     <tr>
#       <th id="T_f576e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f576e_row2_col0" class="data row2 col0" >employee</td>
#       <td id="T_f576e_row2_col1" class="data row2 col1" >phone_number</td>
#       <td id="T_f576e_row2_col2" class="data row2 col2" >Contact number of the employee</td>
#       <td id="T_f576e_row2_col3" class="data row2 col3" >VARCHAR(15)</td>
#       <td id="T_f576e_row2_col4" class="data row2 col4" ></td>
#     </tr>
#     <tr>
#       <th id="T_f576e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f576e_row3_col0" class="data row3 col0" >employee</td>
#       <td id="T_f576e_row3_col1" class="data row3 col1" >email</td>
#       <td id="T_f576e_row3_col2" class="data row3 col2" >Email address of the employee</td>
#       <td id="T_f576e_row3_col3" class="data row3 col3" >VARCHAR(255)</td>
#       <td id="T_f576e_row3_col4" class="data row3 col4" ></td>
#     </tr>
#     <tr>
#       <th id="T_f576e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f576e_row4_col0" class="data row4 col0" >employee</td>
#       <td id="T_f576e_row4_col1" class="data row4 col1" >address</td>
#       <td id="T_f576e_row4_col2" class="data row4 col2" >Residential address of the employee</td>
#       <td id="T_f576e_row4_col3" class="data row4 col3" >VARCHAR(255)</td>
#       <td id="T_f576e_row4_col4" class="data row4 col4" ></td>
#     </tr>
#     <tr>
#       <th id="T_f576e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f576e_row5_col0" class="data row5 col0" >employee</td>
#       <td id="T_f576e_row5_col1" class="data row5 col1" >town_name</td>
#       <td id="T_f576e_row5_col2" class="data row5 col2" >Name of the town where the employee resides</td>
#       <td id="T_f576e_row5_col3" class="data row5 col3" >VARCHAR(255)</td>
#       <td id="T_f576e_row5_col4" class="data row5 col4" ></td>
#     </tr>
#     <tr>
#       <th id="T_f576e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f576e_row6_col0" class="data row6 col0" >employee</td>
#       <td id="T_f576e_row6_col1" class="data row6 col1" >province_name</td>
#       <td id="T_f576e_row6_col2" class="data row6 col2" >Name of the province where the employee resides</td>
#       <td id="T_f576e_row6_col3" class="data row6 col3" >VARCHAR(255)</td>
#       <td id="T_f576e_row6_col4" class="data row6 col4" ></td>
#     </tr>
#     <tr>
#       <th id="T_f576e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f576e_row7_col0" class="data row7 col0" >employee</td>
#       <td id="T_f576e_row7_col1" class="data row7 col1" >position</td>
#       <td id="T_f576e_row7_col2" class="data row7 col2" >Position or job title of the employee</td>
#       <td id="T_f576e_row7_col3" class="data row7 col3" >VARCHAR(255)</td>
#       <td id="T_f576e_row7_col4" class="data row7 col4" ></td>
#     </tr>
#     <tr>
#       <th id="T_f576e_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f576e_row8_col0" class="data row8 col0" >visits</td>
#       <td id="T_f576e_row8_col1" class="data row8 col1" >record_id</td>
#       <td id="T_f576e_row8_col2" class="data row8 col2" >Unique ID assigned to each visit</td>
#       <td id="T_f576e_row8_col3" class="data row8 col3" >int</td>
#       <td id="T_f576e_row8_col4" class="data row8 col4" >water_quality, water_source</td>
#     </tr>
#     <tr>
#       <th id="T_f576e_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_f576e_row9_col0" class="data row9 col0" >visits</td>
#       <td id="T_f576e_row9_col1" class="data row9 col1" >location_id</td>
#       <td id="T_f576e_row9_col2" class="data row9 col2" >ID of the location visited</td>
#       <td id="T_f576e_row9_col3" class="data row9 col3" >varchar(255)</td>
#       <td id="T_f576e_row9_col4" class="data row9 col4" >location</td>
#     </tr>
#   </tbody>
# </table>
# First 10 rows from table: employee
# <style type="text/css">
# #T_d6879 thead th {
#   background-color: lightblue;
#   color: black;
#   font-size: 12pt;
#   text-align: center;
# }
# #T_d6879_row0_col0, #T_d6879_row0_col1, #T_d6879_row0_col2, #T_d6879_row0_col3, #T_d6879_row0_col4, #T_d6879_row0_col5, #T_d6879_row0_col6, #T_d6879_row0_col7, #T_d6879_row1_col0, #T_d6879_row1_col1, #T_d6879_row1_col2, #T_d6879_row1_col3, #T_d6879_row1_col4, #T_d6879_row1_col5, #T_d6879_row1_col6, #T_d6879_row1_col7, #T_d6879_row2_col0, #T_d6879_row2_col1, #T_d6879_row2_col2, #T_d6879_row2_col3, #T_d6879_row2_col4, #T_d6879_row2_col5, #T_d6879_row2_col6, #T_d6879_row2_col7, #T_d6879_row3_col0, #T_d6879_row3_col1, #T_d6879_row3_col2, #T_d6879_row3_col3, #T_d6879_row3_col4, #T_d6879_row3_col5, #T_d6879_row3_col6, #T_d6879_row3_col7, #T_d6879_row4_col0, #T_d6879_row4_col1, #T_d6879_row4_col2, #T_d6879_row4_col3, #T_d6879_row4_col4, #T_d6879_row4_col5, #T_d6879_row4_col6, #T_d6879_row4_col7, #T_d6879_row5_col0, #T_d6879_row5_col1, #T_d6879_row5_col2, #T_d6879_row5_col3, #T_d6879_row5_col4, #T_d6879_row5_col5, #T_d6879_row5_col6, #T_d6879_row5_col7, #T_d6879_row6_col0, #T_d6879_row6_col1, #T_d6879_row6_col2, #T_d6879_row6_col3, #T_d6879_row6_col4, #T_d6879_row6_col5, #T_d6879_row6_col6, #T_d6879_row6_col7, #T_d6879_row7_col0, #T_d6879_row7_col1, #T_d6879_row7_col2, #T_d6879_row7_col3, #T_d6879_row7_col4, #T_d6879_row7_col5, #T_d6879_row7_col6, #T_d6879_row7_col7, #T_d6879_row8_col0, #T_d6879_row8_col1, #T_d6879_row8_col2, #T_d6879_row8_col3, #T_d6879_row8_col4, #T_d6879_row8_col5, #T_d6879_row8_col6, #T_d6879_row8_col7, #T_d6879_row9_col0, #T_d6879_row9_col1, #T_d6879_row9_col2, #T_d6879_row9_col3, #T_d6879_row9_col4, #T_d6879_row9_col5, #T_d6879_row9_col6, #T_d6879_row9_col7 {
#   background-color: #f4f4f4;
# }
# </style>
# <table id="T_d6879">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d6879_level0_col0" class="col_heading level0 col0" >assigned_employee_id</th>
#       <th id="T_d6879_level0_col1" class="col_heading level0 col1" >employee_name</th>
#       <th id="T_d6879_level0_col2" class="col_heading level0 col2" >phone_number</th>
#       <th id="T_d6879_level0_col3" class="col_heading level0 col3" >email</th>
#       <th id="T_d6879_level0_col4" class="col_heading level0 col4" >address</th>
#       <th id="T_d6879_level0_col5" class="col_heading level0 col5" >province_name</th>
#       <th id="T_d6879_level0_col6" class="col_heading level0 col6" >town_name</th>
#       <th id="T_d6879_level0_col7" class="col_heading level0 col7" >position</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d6879_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d6879_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_d6879_row0_col1" class="data row0 col1" >Amara Jengo</td>
#       <td id="T_d6879_row0_col2" class="data row0 col2" >+99637993287 </td>
#       <td id="T_d6879_row0_col3" class="data row0 col3" >None</td>
#       <td id="T_d6879_row0_col4" class="data row0 col4" >36 Pwani Mchangani Road</td>
#       <td id="T_d6879_row0_col5" class="data row0 col5" >Sokoto</td>
#       <td id="T_d6879_row0_col6" class="data row0 col6" >Ilanga</td>
#       <td id="T_d6879_row0_col7" class="data row0 col7" >Field Surveyor</td>
#     </tr>
#     <tr>
#       <th id="T_d6879_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d6879_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_d6879_row1_col1" class="data row1 col1" >Bello Azibo</td>
#       <td id="T_d6879_row1_col2" class="data row1 col2" >+99643864786 </td>
#       <td id="T_d6879_row1_col3" class="data row1 col3" >None</td>
#       <td id="T_d6879_row1_col4" class="data row1 col4" >129 Ziwa La Kioo Road</td>
#       <td id="T_d6879_row1_col5" class="data row1 col5" >Kilimani</td>
#       <td id="T_d6879_row1_col6" class="data row1 col6" >Rural</td>
#       <td id="T_d6879_row1_col7" class="data row1 col7" >Field Surveyor</td>
#     </tr>
#     <tr>
#       <th id="T_d6879_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d6879_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_d6879_row2_col1" class="data row2 col1" >Bakari Iniko</td>
#       <td id="T_d6879_row2_col2" class="data row2 col2" >+99222599041 </td>
#       <td id="T_d6879_row2_col3" class="data row2 col3" >None</td>
#       <td id="T_d6879_row2_col4" class="data row2 col4" >18 Mlima Tazama Avenue</td>
#       <td id="T_d6879_row2_col5" class="data row2 col5" >Hawassa</td>
#       <td id="T_d6879_row2_col6" class="data row2 col6" >Rural</td>
#       <td id="T_d6879_row2_col7" class="data row2 col7" >Field Surveyor</td>
#     </tr>
#     <tr>
#       <th id="T_d6879_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d6879_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_d6879_row3_col1" class="data row3 col1" >Malachi Mavuso</td>
#       <td id="T_d6879_row3_col2" class="data row3 col2" >+99945849900 </td>
#       <td id="T_d6879_row3_col3" class="data row3 col3" >None</td>
#       <td id="T_d6879_row3_col4" class="data row3 col4" >100 Mogadishu Road</td>
#       <td id="T_d6879_row3_col5" class="data row3 col5" >Akatsi</td>
#       <td id="T_d6879_row3_col6" class="data row3 col6" >Lusaka</td>
#       <td id="T_d6879_row3_col7" class="data row3 col7" >Field Surveyor</td>
#     </tr>
#     <tr>
#       <th id="T_d6879_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d6879_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_d6879_row4_col1" class="data row4 col1" >Cheche Buhle</td>
#       <td id="T_d6879_row4_col2" class="data row4 col2" >+99381679640 </td>
#       <td id="T_d6879_row4_col3" class="data row4 col3" >None</td>
#       <td id="T_d6879_row4_col4" class="data row4 col4" >1 Savanna Street</td>
#       <td id="T_d6879_row4_col5" class="data row4 col5" >Akatsi</td>
#       <td id="T_d6879_row4_col6" class="data row4 col6" >Rural</td>
#       <td id="T_d6879_row4_col7" class="data row4 col7" >Field Surveyor</td>
#     </tr>
#     <tr>
#       <th id="T_d6879_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d6879_row5_col0" class="data row5 col0" >5</td>
#       <td id="T_d6879_row5_col1" class="data row5 col1" >Zuriel Matembo</td>
#       <td id="T_d6879_row5_col2" class="data row5 col2" >+99034075111 </td>
#       <td id="T_d6879_row5_col3" class="data row5 col3" >None</td>
#       <td id="T_d6879_row5_col4" class="data row5 col4" >26 Bahari Ya Faraja Road</td>
#       <td id="T_d6879_row5_col5" class="data row5 col5" >Kilimani</td>
#       <td id="T_d6879_row5_col6" class="data row5 col6" >Rural</td>
#       <td id="T_d6879_row5_col7" class="data row5 col7" >Field Surveyor</td>
#     </tr>
#     <tr>
#       <th id="T_d6879_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d6879_row6_col0" class="data row6 col0" >6</td>
#       <td id="T_d6879_row6_col1" class="data row6 col1" >Deka Osumare</td>
#       <td id="T_d6879_row6_col2" class="data row6 col2" >+99379364631 </td>
#       <td id="T_d6879_row6_col3" class="data row6 col3" >None</td>
#       <td id="T_d6879_row6_col4" class="data row6 col4" >104 Kenyatta Street</td>
#       <td id="T_d6879_row6_col5" class="data row6 col5" >Akatsi</td>
#       <td id="T_d6879_row6_col6" class="data row6 col6" >Rural</td>
#       <td id="T_d6879_row6_col7" class="data row6 col7" >Field Surveyor</td>
#     </tr>
#     <tr>
#       <th id="T_d6879_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d6879_row7_col0" class="data row7 col0" >7</td>
#       <td id="T_d6879_row7_col1" class="data row7 col1" >Lalitha Kaburi</td>
#       <td id="T_d6879_row7_col2" class="data row7 col2" >+99681623240 </td>
#       <td id="T_d6879_row7_col3" class="data row7 col3" >None</td>
#       <td id="T_d6879_row7_col4" class="data row7 col4" >145 Sungura Amanpour Road</td>
#       <td id="T_d6879_row7_col5" class="data row7 col5" >Kilimani</td>
#       <td id="T_d6879_row7_col6" class="data row7 col6" >Rural</td>
#       <td id="T_d6879_row7_col7" class="data row7 col7" >Field Surveyor</td>
#     </tr>
#     <tr>
#       <th id="T_d
# First 10 rows from table: global_water_access
# <style type="text/css">
# #T_181d3 thead th {
#   background-color: lightblue;
#   color: black;
#   font-size: 12pt;
#   text-align: center;
# }
# #T_181d3_row0_col0, #T_181d3_row0_col1, #T_181d3_row0_col2, #T_181d3_row0_col3, #T_181d3_row0_col4, #T_181d3_row0_col5, #T_181d3_row0_col6, #T_181d3_row0_col7, #T_181d3_row0_col8, #T_181d3_row0_col9, #T_181d3_row0_col10, #T_181d3_row0_col11, #T_181d3_row0_col12, #T_181d3_row0_col13, #T_181d3_row0_col14, #T_181d3_row0_col15, #T_181d3_row0_col16, #T_181d3_row1_col0, #T_181d3_row1_col1, #T_181d3_row1_col2, #T_181d3_row1_col3, #T_181d3_row1_col4, #T_181d3_row1_col5, #T_181d3_row1_col6, #T_181d3_row1_col7, #T_181d3_row1_col8, #T_181d3_row1_col9, #T_181d3_row1_col10, #T_181d3_row1_col11, #T_181d3_row1_col12, #T_181d3_row1_col13, #T_181d3_row1_col14, #T_181d3_row1_col15, #T_181d3_row1_col16, #T_181d3_row2_col0, #T_181d3_row2_col1, #T_181d3_row2_col2, #T_181d3_row2_col3, #T_181d3_row2_col4, #T_181d3_row2_col5, #T_181d3_row2_col6, #T_181d3_row2_col7, #T_181d3_row2_col8, #T_181d3_row2_col9, #T_181d3_row2_col10, #T_181d3_row2_col11, #T_181d3_row2_col12, #T_181d3_row2_col13, #T_181d3_row2_col14, #T_181d3_row2_col15, #T_181d3_row2_col16, #T_181d3_row3_col0, #T_181d3_row3_col1, #T_181d3_row3_col2, #T_181d3_row3_col3, #T_181d3_row3_col4, #T_181d3_row3_col5, #T_181d3_row3_col6, #T_181d3_row3_col7, #T_181d3_row3_col8, #T_181d3_row3_col9, #T_181d3_row3_col10, #T_181d3_row3_col11, #T_181d3_row3_col12, #T_181d3_row3_col13, #T_181d3_row3_col14, #T_181d3_row3_col15, #T_181d3_row3_col16, #T_181d3_row4_col0, #T_181d3_row4_col1, #T_181d3_row4_col2, #T_181d3_row4_col3, #T_181d3_row4_col4, #T_181d3_row4_col5, #T_181d3_row4_col6, #T_181d3_row4_col7, #T_181d3_row4_col8, #T_181d3_row4_col9, #T_181d3_row4_col10, #T_181d3_row4_col11, #T_181d3_row4_col12, #T_181d3_row4_col13, #T_181d3_row4_col14, #T_181d3_row4_col15, #T_181d3_row4_col16, #T_181d3_row5_col0, #T_181d3_row5_col1, #T_181d3_row5_col2, #T_181d3_row5_col3, #T_181d3_row5_col4, #T_181d3_row5_col5, #T_181d3_row5_col6, #T_181d3_row5_col7, #T_181d3_row5_col8, #T_181d3_row5_col9, #T_181d3_row5_col10, #T_181d3_row5_col11, #T_181d3_row5_col12, #T_181d3_row5_col13, #T_181d3_row5_col14, #T_181d3_row5_col15, #T_181d3_row5_col16, #T_181d3_row6_col0, #T_181d3_row6_col1, #T_181d3_row6_col2, #T_181d3_row6_col3, #T_181d3_row6_col4, #T_181d3_row6_col5, #T_181d3_row6_col6, #T_181d3_row6_col7, #T_181d3_row6_col8, #T_181d3_row6_col9, #T_181d3_row6_col10, #T_181d3_row6_col11, #T_181d3_row6_col12, #T_181d3_row6_col13, #T_181d3_row6_col14, #T_181d3_row6_col15, #T_181d3_row6_col16, #T_181d3_row7_col0, #T_181d3_row7_col1, #T_181d3_row7_col2, #T_181d3_row7_col3, #T_181d3_row7_col4, #T_181d3_row7_col5, #T_181d3_row7_col6, #T_181d3_row7_col7, #T_181d3_row7_col8, #T_181d3_row7_col9, #T_181d3_row7_col10, #T_181d3_row7_col11, #T_181d3_row7_col12, #T_181d3_row7_col13, #T_181d3_row7_col14, #T_181d3_row7_col15, #T_181d3_row7_col16, #T_181d3_row8_col0, #T_181d3_row8_col1, #T_181d3_row8_col2, #T_181d3_row8_col3, #T_181d3_row8_col4, #T_181d3_row8_col5, #T_181d3_row8_col6, #T_181d3_row8_col7, #T_181d3_row8_col8, #T_181d3_row8_col9, #T_181d3_row8_col10, #T_181d3_row8_col11, #T_181d3_row8_col12, #T_181d3_row8_col13, #T_181d3_row8_col14, #T_181d3_row8_col15, #T_181d3_row8_col16, #T_181d3_row9_col0, #T_181d3_row9_col1, #T_181d3_row9_col2, #T_181d3_row9_col3, #T_181d3_row9_col4, #T_181d3_row9_col5, #T_181d3_row9_col6, #T_181d3_row9_col7, #T_181d3_row9_col8, #T_181d3_row9_col9, #T_181d3_row9_col10, #T_181d3_row9_col11, #T_181d3_row9_col12, #T_181d3_row9_col13, #T_181d3_row9_col14, #T_181d3_row9_col15, #T_181d3_row9_col16 {
#   background-color: #f4f4f4;
# }
# </style>
# <table id="T_181d3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_181d3_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_181d3_level0_col1" class="col_heading level0 col1" >region</th>
#       <th id="T_181d3_level0_col2" class="col_heading level0 col2" >year</th>
#       <th id="T_181d3_level0_col3" class="col_heading level0 col3" >pop_n</th>
#       <th id="T_181d3_level0_col4" class="col_heading level0 col4" >pop_u</th>
#       <th id="T_181d3_level0_col5" class="col_heading level0 col5" >wat_bas_n</th>
#       <th id="T_181d3_level0_col6" class="col_heading level0 col6" >wat_lim_n</th>
#       <th id="T_181d3_level0_col7" class="col_heading level0 col7" >wat_unimp_n</th>
#       <th id="T_181d3_level0_col8" class="col_heading level0 col8" >wat_sur_n</th>
#       <th id="T_181d3_level0_col9" class="col_heading level0 col9" >wat_bas_r</th>
#       <th id="T_181d3_level0_col10" class="col_heading level0 col10" >wat_lim_r</th>
#       <th id="T_181d3_level0_col11" class="col_heading level0 col11" >wat_unimp_r</th>
#       <th id="T_181d3_level0_col12" class="col_heading level0 col12" >wat_sur_r</th>
#       <th id="T_181d3_level0_col13" class="col_heading level0 col13" >wat_bas_u</th>
#       <th id="T_181d3_level0_col14" class="col_heading level0 col14" >wat_lim_u</th>
#       <th id="T_181d3_level0_col15" class="col_heading level0 col15" >wat_unimp_u</th>
#       <th id="T_181d3_level0_col16" class="col_heading level0 col16" >wat_sur_u</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_181d3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_181d3_row0_col0" class="data row0 col0" >Afghanistan</td>
#       <td id="T_181d3_row0_col1" class="data row0 col1" >South Asia</td>
#       <td id="T_181d3_row0_col2" class="data row0 col2" >2015</td>
#       <td id="T_181d3_row0_col3" class="data row0 col3" >34413.600000</td>
#       <td id="T_181d3_row0_col4" class="data row0 col4" >24.803000</td>
#       <td id="T_181d3_row0_col5" class="data row0 col5" >61.339800</td>
#       <td id="T_181d3_row0_col6" class="data row0 col6" >3.511200</td>
#       <td id="T_181d3_row0_col7" class="data row0 col7" >22.168800</td>
#       <td id="T_181d3_row0_col8" class="data row0 col8" >12.980200</td>
#       <td id="T_181d3_row0_col9" class="data row0 col9" >52.988500</td>
#       <td id="T_181d3_row0_col10" class="data row0 col10" >3.861140</td>
#       <td id="T_181d3_row0_col11" class="data row0 col11" >26.553300</td>
#       <td id="T_181d3_row0_col12" class="data row0 col12" >16.597100</td>
#       <td id="T_181d3_row0_col13" class="data row0 col13" >86.658900</td>
#       <td id="T_181d3_row0_col14" class="data row0 col14" >2.450270</td>
#       <td id="T_181d3_row0_col15" class="data row0 col15" >8.876040</td>
#       <td id="T_181d3_row0_col16" class="data row0 col16" >2.014750</td>
#     </tr>
#     <tr>
#       <th id="T_181d3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_181d3_row1_col0" class="data row1 col0" >Afghanistan</td>
#       <td id="T_181d3_row1_col1" class="data row1 col1" >South Asia</td>
#       <td id="T_181d3_row1_col2" class="data row1 col2" >2020</td>
#       <td id="T_181d3_row1_col3" class="data row1 col3" >38928.300000</td>
#       <td id="T_181d3_row1_col4" class="data row1 col4" >26.026000</td>
#       <td id="T_181d3_row1_col5" class="data row1 col5" >75.091400</td>
#       <td id="T_181d3_row1_col6" class="data row1 col6" >1.447540</td>
#       <td id="T_181d3_row1_col7" class="data row1 col7" >14.560300</td>
#       <td id="T_181d3_row1_col8" class="data row1 col8" >8.900780</td>
#       <td id="T_181d3_row1_col9" class="data row1 col9" >66.327900</td>
#       <td id="T_181d3_row1_col10" class="data row1 col10" >1.956820</td>
#       <td id="T_181d3_row1_col11" class="data row1 col11" >19.682900</td>
#       <td id="T_181d3_row1_col12" class="data row1 col12" >12.032300</td>
#       <td id="T_181d3_row1_col13" class="data row1 col13" >100.000000</td>
#       <td id="T_181d3_row1_col14" class="data row1 col14" >0.000000</td>
#       <td id="T_181d3_row1_col15" class="data row1 col15" >0.000000</td>
#       <td id="T_181d3_row1_col16" class="data row1 col16" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_181d3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_181d3_row2_col0" class="data row2 col0" >Albania</td>
#       <td id="T_181d
# First 10 rows from table: location
# <style type="text/css">
# #T_b650d thead th {
#   background-color: lightblue;
#   color: black;
#   font-size: 12pt;
#   text-align: center;
# }
# #T_b650d_row0_col0, #T_b650d_row0_col1, #T_b650d_row0_col2, #T_b650d_row0_col3, #T_b650d_row0_col4, #T_b650d_row1_col0, #T_b650d_row1_col1, #T_b650d_row1_col2, #T_b650d_row1_col3, #T_b650d_row1_col4, #T_b650d_row2_col0, #T_b650d_row2_col1, #T_b650d_row2_col2, #T_b650d_row2_col3, #T_b650d_row2_col4, #T_b650d_row3_col0, #T_b650d_row3_col1, #T_b650d_row3_col2, #T_b650d_row3_col3, #T_b650d_row3_col4, #T_b650d_row4_col0, #T_b650d_row4_col1, #T_b650d_row4_col2, #T_b650d_row4_col3, #T_b650d_row4_col4, #T_b650d_row5_col0, #T_b650d_row5_col1, #T_b650d_row5_col2, #T_b650d_row5_col3, #T_b650d_row5_col4, #T_b650d_row6_col0, #T_b650d_row6_col1, #T_b650d_row6_col2, #T_b650d_row6_col3, #T_b650d_row6_col4, #T_b650d_row7_col0, #T_b650d_row7_col1, #T_b650d_row7_col2, #T_b650d_row7_col3, #T_b650d_row7_col4, #T_b650d_row8_col0, #T_b650d_row8_col1, #T_b650d_row8_col2, #T_b650d_row8_col3, #T_b650d_row8_col4, #T_b650d_row9_col0, #T_b650d_row9_col1, #T_b650d_row9_col2, #T_b650d_row9_col3, #T_b650d_row9_col4 {
#   background-color: #f4f4f4;
# }
# </style>
# <table id="T_b650d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b650d_level0_col0" class="col_heading level0 col0" >location_id</th>
#       <th id="T_b650d_level0_col1" class="col_heading level0 col1" >address</th>
#       <th id="T_b650d_level0_col2" class="col_heading level0 col2" >province_name</th>
#       <th id="T_b650d_level0_col3" class="col_heading level0 col3" >town_name</th>
#       <th id="T_b650d_level0_col4" class="col_heading level0 col4" >location_type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b650d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b650d_row0_col0" class="data row0 col0" >AkHa00000</td>
#       <td id="T_b650d_row0_col1" class="data row0 col1" >2 Addis Ababa Road</td>
#       <td id="T_b650d_row0_col2" class="data row0 col2" >Akatsi</td>
#       <td id="T_b650d_row0_col3" class="data row0 col3" >Harare</td>
#       <td id="T_b650d_row0_col4" class="data row0 col4" >Urban</td>
#     </tr>
#     <tr>
#       <th id="T_b650d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b650d_row1_col0" class="data row1 col0" >AkHa00001</td>
#       <td id="T_b650d_row1_col1" class="data row1 col1" >10 Addis Ababa Road</td>
#       <td id="T_b650d_row1_col2" class="data row1 col2" >Akatsi</td>
#       <td id="T_b650d_row1_col3" class="data row1 col3" >Harare</td>
#       <td id="T_b650d_row1_col4" class="data row1 col4" >Urban</td>
#     </tr>
#     <tr>
#       <th id="T_b650d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b650d_row2_col0" class="data row2 col0" >AkHa00002</td>
#       <td id="T_b650d_row2_col1" class="data row2 col1" >9 Addis Ababa Road</td>
#       <td id="T_b650d_row2_col2" class="data row2 col2" >Akatsi</td>
#       <td id="T_b650d_row2_col3" class="data row2 col3" >Harare</td>
#       <td id="T_b650d_row2_col4" class="data row2 col4" >Urban</td>
#     </tr>
#     <tr>
#       <th id="T_b650d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b650d_row3_col0" class="data row3 col0" >AkHa00003</td>
#       <td id="T_b650d_row3_col1" class="data row3 col1" >139 Addis Ababa Road</td>
#       <td id="T_b650d_row3_col2" class="data row3 col2" >Akatsi</td>
#       <td id="T_b650d_row3_col3" class="data row3 col3" >Harare</td>
#       <td id="T_b650d_row3_col4" class="data row3 col4" >Urban</td>
#     </tr>
#     <tr>
#       <th id="T_b650d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b650d_row4_col0" class="data row4 col0" >AkHa00004</td>
#       <td id="T_b650d_row4_col1" class="data row4 col1" >17 Addis Ababa Road</td>
#       <td id="T_b650d_row4_col2" class="data row4 col2" >Akatsi</td>
#       <td id="T_b650d_row4_col3" class="data row4 col3" >Harare</td>
#       <td id="T_b650d_row4_col4" class="data row4 col4" >Urban</td>
#     </tr>
#     <tr>
#       <th id="T_b650d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b650d_row5_col0" class="data row5 col0" >AkHa00005</td>
#       <td id="T_b650d_row5_col1" class="data row5 col1" >125 Addis Ababa Road</td>
#       <td id="T_b650d_row5_col2" class="data row5 col2" >Akatsi</td>
#       <td id="T_b650d_row5_col3" class="data row5 col3" >Harare</td>
#       <td id="T_b650d_row5_col4" class="data row5 col4" >Urban</td>
#     </tr>
#     <tr>
#       <th id="T_b650d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b650d_row6_col0" class="data row6 col0" >AkHa00006</td>
#       <td id="T_b650d_row6_col1" class="data row6 col1" >98 Addis Ababa Road</td>
#       <td id="T_b650d_row6_col2" class="data row6 col2" >Akatsi</td>
#       <td id="T_b650d_row6_col3" class="data row6 col3" >Harare</td>
#       <td id="T_b650d_row6_col4" class="data row6 col4" >Urban</td>
#     </tr>
#     <tr>
#       <th id="T_b650d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b650d_row7_col0" class="data row7 col0" >AkHa00007</td>
#       <td id="T_b650d_row7_col1" class="data row7 col1" >21 Addis Ababa Road</td>
#       <td id="T_b650d_row7_col2" class="data row7 col2" >Akatsi</td>
#       <td id="T_b650d_row7_col3" class="data row7 col3" >Harare</td>
#       <td id="T_b650d_row7_col4" class="data row7 col4" >Urban</td>
#     </tr>
#     <tr>
#       <th id="T_b650d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b650d_row8_col0" class="data row8 col0" >AkHa00008</td>
#       <td id="T_b650d_row8_col1" class="data row8 col1" >11 Addis Ababa Road</td>
#       <td id="T_b650d_row8_col2" class="data row8 col2" >Akatsi</td>
#       <td id="T_b650d_row8_col3" class="data row8 col3" >Harare</td>
#       <td id="T_b650d_row8_col4" class="data row8 col4" >Urban</td>
#     </tr>
#     <tr>
#       <th id="T_b650d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b650d_row9_col0" class="data row9 col0" >AkHa00009</td>
#       <td id="T_b650d_row9_col1" class="data row9 col1" >6 Addis Ababa Road</td>
#       <td id="T_b650d_row9_col2" class="data row9 col2" >Akatsi</td>
#       <td id="T_b650d_row9_col3" class="data row9 col3" >Harare</td>
#       <td id="T_b650d_row9_col4" class="data row9 col4" >Urban</td>
#     </tr>
#   </tbody>
# </table>
# First 10 rows from table: visits
# <style type="text/css">
# #T_e1cbe thead th {
#   background-color: lightblue;
#   color: black;
#   font-size: 12pt;
#   text-align: center;
# }
# #T_e1cbe_row0_col0, #T_e1cbe_row0_col1, #T_e1cbe_row0_col2, #T_e1cbe_row0_col3, #T_e1cbe_row0_col4, #T_e1cbe_row0_col5, #T_e1cbe_row0_col6, #T_e1cbe_row1_col0, #T_e1cbe_row1_col1, #T_e1cbe_row1_col2, #T_e1cbe_row1_col3, #T_e1cbe_row1_col4, #T_e1cbe_row1_col5, #T_e1cbe_row1_col6, #T_e1cbe_row2_col0, #T_e1cbe_row2_col1, #T_e1cbe_row2_col2, #T_e1cbe_row2_col3, #T_e1cbe_row2_col4, #T_e1cbe_row2_col5, #T_e1cbe_row2_col6, #T_e1cbe_row3_col0, #T_e1cbe_row3_col1, #T_e1cbe_row3_col2, #T_e1cbe_row3_col3, #T_e1cbe_row3_col4, #T_e1cbe_row3_col5, #T_e1cbe_row3_col6, #T_e1cbe_row4_col0, #T_e1cbe_row4_col1, #T_e1cbe_row4_col2, #T_e1cbe_row4_col3, #T_e1cbe_row4_col4, #T_e1cbe_row4_col5, #T_e1cbe_row4_col6, #T_e1cbe_row5_col0, #T_e1cbe_row5_col1, #T_e1cbe_row5_col2, #T_e1cbe_row5_col3, #T_e1cbe_row5_col4, #T_e1cbe_row5_col5, #T_e1cbe_row5_col6, #T_e1cbe_row6_col0, #T_e1cbe_row6_col1, #T_e1cbe_row6_col2, #T_e1cbe_row6_col3, #T_e1cbe_row6_col4, #T_e1cbe_row6_col5, #T_e1cbe_row6_col6, #T_e1cbe_row7_col0, #T_e1cbe_row7_col1, #T_e1cbe_row7_col2, #T_e1cbe_row7_col3, #T_e1cbe_row7_col4, #T_e1cbe_row7_col5, #T_e1cbe_row7_col6, #T_e1cbe_row8_col0, #T_e1cbe_row8_col1, #T_e1cbe_row8_col2, #T_e1cbe_row8_col3, #T_e1cbe_row8_col4, #T_e1cbe_row8_col5, #T_e1cbe_row8_col6, #T_e1cbe_row9_col0, #T_e1cbe_row9_col1, #T_e1cbe_row9_col2, #T_e1cbe_row9_col3, #T_e1cbe_row9_col4, #T_e1cbe_row9_col5, #T_e1cbe_row9_col6 {
#   background-color: #f4f4f4;
# }
# </style>
# <table id="T_e1cbe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e1cbe_level0_col0" class="col_heading level0 col0" >record_id</th>
#       <th id="T_e1cbe_level0_col1" class="col_heading level0 col1" >location_id</th>
#       <th id="T_e1cbe_level0_col2" class="col_heading level0 col2" >source_id</th>
#       <th id="T_e1cbe_level0_col3" class="col_heading level0 col3" >time_of_record</th>
#       <th id="T_e1cbe_level0_col4" class="col_heading level0 col4" >visit_count</th>
#       <th id="T_e1cbe_level0_col5" class="col_heading level0 col5" >time_in_queue</th>
#       <th id="T_e1cbe_level0_col6" class="col_heading level0 col6" >assigned_employee_id</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e1cbe_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e1cbe_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_e1cbe_row0_col1" class="data row0 col1" >SoIl32582</td>
#       <td id="T_e1cbe_row0_col2" class="data row0 col2" >SoIl32582224</td>
#       <td id="T_e1cbe_row0_col3" class="data row0 col3" >2021-01-01 09:10:00</td>
#       <td id="T_e1cbe_row0_col4" class="data row0 col4" >1</td>
#       <td id="T_e1cbe_row0_col5" class="data row0 col5" >15</td>
#       <td id="T_e1cbe_row0_col6" class="data row0 col6" >12</td>
#     </tr>
#     <tr>
#       <th id="T_e1cbe_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e1cbe_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_e1cbe_row1_col1" class="data row1 col1" >KiRu28935</td>
#       <td id="T_e1cbe_row1_col2" class="data row1 col2" >KiRu28935224</td>
#       <td id="T_e1cbe_row1_col3" class="data row1 col3" >2021-01-01 09:17:00</td>
#       <td id="T_e1cbe_row1_col4" class="data row1 col4" >1</td>
#       <td id="T_e1cbe_row1_col5" class="data row1 col5" >0</td>
#       <td id="T_e1cbe_row1_col6" class="data row1 col6" >46</td>
#     </tr>
#     <tr>
#       <th id="T_e1cbe_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e1cbe_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_e1cbe_row2_col1" class="data row2 col1" >HaRu19752</td>
#       <td id="T_e1cbe_row2_col2" class="data row2 col2" >HaRu19752224</td>
#       <td id="T_e1cbe_row2_col3" class="data row2 col3" >2021-01-01 09:36:00</td>
#       <td id="T_e1cbe_row2_col4" class="data row2 col4" >1</td>
#       <td id="T_e1cbe_row2_col5" class="data row2 col5" >62</td>
#       <td id="T_e1cbe_row2_col6" class="data row2 col6" >40</td>
#     </tr>
#     <tr>
#       <th id="T_e1cbe_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e1cbe_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_e1cbe_row3_col1" class="data row3 col1" >AkLu01628</td>
#       <td id="T_e1cbe_row3_col2" class="data row3 col2" >AkLu01628224</td>
#       <td id="T_e1cbe_row3_col3" class="data row3 col3" >2021-01-01 09:53:00</td>
#       <td id="T_e1cbe_row3_col4" class="data row3 col4" >1</td>
#       <td id="T_e1cbe_row3_col5" class="data row3 col5" >0</td>
#       <td id="T_e1cbe_row3_col6" class="data row3 col6" >1</td>
#     </tr>
#     <tr>
#       <th id="T_e1cbe_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e1cbe_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_e1cbe_row4_col1" class="data row4 col1" >AkRu03357</td>
#       <td id="T_e1cbe_row4_col2" class="data row4 col2" >AkRu03357224</td>
#       <td id="T_e1cbe_row4_col3" class="data row4 col3" >2021-01-01 10:11:00</td>
#       <td id="T_e1cbe_row4_col4" class="data row4 col4" >1</td>
#       <td id="T_e1cbe_row4_col5" class="data row4 col5" >28</td>
#       <td id="T_e1cbe_row4_col6" class="data row4 col6" >14</td>
#     </tr>
#     <tr>
#       <th id="T_e1cbe_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e1cbe_row5_col0" class="data row5 col0" >5</td>
#       <td id="T_e1cbe_row5_col1" class="data row5 col1" >KiRu29315</td>
#       <td id="T_e1cbe_row5_col2" class="data row5 col2" >KiRu29315224</td>
#       <td id="T_e1cbe_row5_col3" class="data row5 col3" >2021-01-01 10:17:00</td>
#       <td id="T_e1cbe_row5_col4" class="data row5 col4" >1</td>
#       <td id="T_e1cbe_row5_col5" class="data row5 col5" >9</td>
#       <td id="T_e1cbe_row5_col6" class="data row5 col6" >40</td>
#     </tr>
#     <tr>
#       <th id="T_e1cbe_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e1cbe_row6_col0" class="data row6 col0" >6</td>
#       <td id="T_e1cbe_row6_col1" class="data row6 col1" >AkRu05234</td>
#       <td id="T_e1cbe_row6_col2" class="data row6 col2" >AkRu05234224</td>
#       <td id="T_e1cbe_row6_col3" class="data row6 col3" >2021-01-01 10:18:00</td>
#       <td id="T_e1cbe_row6_col4" class="data row6 col4" >1</td>
#       <td id="T_e1cbe_row6_col5" class="data row6 col5" >0</td>
#       <td id="T_e1cbe_row6_col6" class="data row6 col6" >30</td>
#     </tr>
#     <tr>
#       <th id="T_e1cbe_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e1cbe_row7_col0" class="data row7 col0" >7</td>
#       <td id="T_e1cbe_row7_col1" class="data row7 col1" >KiRu28520</td>
#       <td id="T_e1cbe_row7_col2" class="data row7 col2" >KiRu28520224</td>
#       <td id="T_e1cbe_row7_col3" class="data row7 col3" >2021-01-01 10:28:00</td>
#       <td id="T_e1cbe_row7_col4" class="data row7 col4" >1</td>
#       <td id="T_e1cbe_row7_col5" class="data row7 col5" >0</td>
#       <td id="T_e1cbe_row7_col6" class="data row7 col6" >34</td>
#     </tr>
#     <tr>
#       <th id="T_e1cbe_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e1cbe_row8_col0" class="data row8 col0" >8</td>
#       <td id="T_e1cbe_row8_col1" class="data row8 col1" >HaZa21742</td>
#       <td id="T_e1cbe_row8_col2" class="data row8 col2" >HaZa21742224</td>
#       <td id="T_e1cbe_row8_col3" class="data row8 col3" >2021-01-01 10:37:00</td>
#       <td id="T_e1cbe_row8_col4" class="data row8 col4" >1</td>
#       <td id="T_e1cbe_row8_col5" class="data row8 col5" >0</td>
#       <td id="T_e1cbe_row8_col6" class="data row8 col6" >6</td>
#     </tr>
#     <tr>
#       <th id="T_e1cbe_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_e1cbe_row9_col0" class="data row9 col0" >9</td>
#       <td id="T_e1cbe_row9_col1" class="data row9 col1" >AmDa12214</td>
#       <td id="T_e1cbe_row9_col2" class="data row9 col2" >AmDa12214224</td>
#       <td id="T_e1cbe_row9_col3" class="data row9 col3" >2021-01-01 10:58:00</td>
#       <td id="T_e1cbe_row9_col4" class="data row9 col4" >1</td>
#       <td id="T_e1cbe_row9_col5" class="dat
# First 10 rows from table: water_quality
# <style type="text/css">
# #T_d7116 thead th {
#   background-color: lightblue;
#   color: black;
#   font-size: 12pt;
#   text-align: center;
# }
# #T_d7116_row0_col0, #T_d7116_row0_col1, #T_d7116_row0_col2, #T_d7116_row1_col0, #T_d7116_row1_col1, #T_d7116_row1_col2, #T_d7116_row2_col0, #T_d7116_row2_col1, #T_d7116_row2_col2, #T_d7116_row3_col0, #T_d7116_row3_col1, #T_d7116_row3_col2, #T_d7116_row4_col0, #T_d7116_row4_col1, #T_d7116_row4_col2, #T_d7116_row5_col0, #T_d7116_row5_col1, #T_d7116_row5_col2, #T_d7116_row6_col0, #T_d7116_row6_col1, #T_d7116_row6_col2, #T_d7116_row7_col0, #T_d7116_row7_col1, #T_d7116_row7_col2, #T_d7116_row8_col0, #T_d7116_row8_col1, #T_d7116_row8_col2, #T_d7116_row9_col0, #T_d7116_row9_col1, #T_d7116_row9_col2 {
#   background-color: #f4f4f4;
# }
# </style>
# <table id="T_d7116">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d7116_level0_col0" class="col_heading level0 col0" >record_id</th>
#       <th id="T_d7116_level0_col1" class="col_heading level0 col1" >subjective_quality_score</th>
#       <th id="T_d7116_level0_col2" class="col_heading level0 col2" >visit_count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d7116_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d7116_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_d7116_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_d7116_row0_col2" class="data row0 col2" >1</td>
#     </tr>
#     <tr>
#       <th id="T_d7116_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d7116_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_d7116_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_d7116_row1_col2" class="data row1 col2" >1</td>
#     </tr>
#     <tr>
#       <th id="T_d7116_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d7116_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_d7116_row2_col1" class="data row2 col1" >5</td>
#       <td id="T_d7116_row2_col2" class="data row2 col2" >1</td>
#     </tr>
#     <tr>
#       <th id="T_d7116_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d7116_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_d7116_row3_col1" class="data row3 col1" >10</td>
#       <td id="T_d7116_row3_col2" class="data row3 col2" >1</td>
#     </tr>
#     <tr>
#       <th id="T_d7116_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d7116_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_d7116_row4_col1" class="data row4 col1" >4</td>
#       <td id="T_d7116_row4_col2" class="data row4 col2" >1</td>
#     </tr>
#     <tr>
#       <th id="T_d7116_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d7116_row5_col0" class="data row5 col0" >5</td>
#       <td id="T_d7116_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_d7116_row5_col2" class="data row5 col2" >1</td>
#     </tr>
#     <tr>
#       <th id="T_d7116_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d7116_row6_col0" class="data row6 col0" >6</td>
#       <td id="T_d7116_row6_col1" class="data row6 col1" >9</td>
#       <td id="T_d7116_row6_col2" class="data row6 col2" >1</td>
#     </tr>
#     <tr>
#       <th id="T_d7116_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d7116_row7_col0" class="data row7 col0" >7</td>
#       <td id="T_d7116_row7_col1" class="data row7 col1" >10</td>
#       <td id="T_d7116_row7_col2" class="data row7 col2" >1</td>
#     </tr>
#     <tr>
#       <th id="T_d7116_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_d7116_row8_col0" class="data row8 col0" >8</td>
#       <td id="T_d7116_row8_col1" class="data row8 col1" >2</td>
#       <td id="T_d7116_row8_col2" class="data row8 col2" >1</td>
#     </tr>
#     <tr>
#       <th id="T_d7116_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_d7116_row9_col0" class="data row9 col0" >9</td>
#       <td id="T_d7116_row9_col1" class="data row9 col1" >10</td>
#       <td id="T_d7116_row9_col2" class="data row9 col2" >1</td>
#     </tr>
#   </tbody>
# </table>
# First 10 rows from table: water_source
# <style type="text/css">
# #T_fe862 thead th {
#   background-color: lightblue;
#   color: black;
#   font-size: 12pt;
#   text-align: center;
# }
# #T_fe862_row0_col0, #T_fe862_row0_col1, #T_fe862_row0_col2, #T_fe862_row1_col0, #T_fe862_row1_col1, #T_fe862_row1_col2, #T_fe862_row2_col0, #T_fe862_row2_col1, #T_fe862_row2_col2, #T_fe862_row3_col0, #T_fe862_row3_col1, #T_fe862_row3_col2, #T_fe862_row4_col0, #T_fe862_row4_col1, #T_fe862_row4_col2, #T_fe862_row5_col0, #T_fe862_row5_col1, #T_fe862_row5_col2, #T_fe862_row6_col0, #T_fe862_row6_col1, #T_fe862_row6_col2, #T_fe862_row7_col0, #T_fe862_row7_col1, #T_fe862_row7_col2, #T_fe862_row8_col0, #T_fe862_row8_col1, #T_fe862_row8_col2, #T_fe862_row9_col0, #T_fe862_row9_col1, #T_fe862_row9_col2 {
#   background-color: #f4f4f4;
# }
# </style>
# <table id="T_fe862">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fe862_level0_col0" class="col_heading level0 col0" >source_id</th>
#       <th id="T_fe862_level0_col1" class="col_heading level0 col1" >type_of_water_source</th>
#       <th id="T_fe862_level0_col2" class="col_heading level0 col2" >number_of_people_served</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fe862_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fe862_row0_col0" class="data row0 col0" >AkHa00000224</td>
#       <td id="T_fe862_row0_col1" class="data row0 col1" >tap_in_home</td>
#       <td id="T_fe862_row0_col2" class="data row0 col2" >956</td>
#     </tr>
#     <tr>
#       <th id="T_fe862_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fe862_row1_col0" class="data row1 col0" >AkHa00001224</td>
#       <td id="T_fe862_row1_col1" class="data row1 col1" >tap_in_home_broken</td>
#       <td id="T_fe862_row1_col2" class="data row1 col2" >930</td>
#     </tr>
#     <tr>
#       <th id="T_fe862_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_fe862_row2_col0" class="data row2 col0" >AkHa00002224</td>
#       <td id="T_fe862_row2_col1" class="data row2 col1" >tap_in_home_broken</td>
#       <td id="T_fe862_row2_col2" class="data row2 col2" >486</td>
#     </tr>
#     <tr>
#       <th id="T_fe862_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_fe862_row3_col0" class="data row3 col0" >AkHa00003224</td>
#       <td id="T_fe862_row3_col1" class="data row3 col1" >well</td>
#       <td id="T_fe862_row3_col2" class="data row3 col2" >364</td>
#     </tr>
#     <tr>
#       <th id="T_fe862_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_fe862_row4_col0" class="data row4 col0" >AkHa00004224</td>
#       <td id="T_fe862_row4_col1" class="data row4 col1" >tap_in_home_broken</td>
#       <td id="T_fe862_row4_col2" class="data row4 col2" >942</td>
#     </tr>
#     <tr>
#       <th id="T_fe862_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_fe862_row5_col0" class="data row5 col0" >AkHa00005224</td>
#       <td id="T_fe862_row5_col1" class="data row5 col1" >tap_in_home</td>
#       <td id="T_fe862_row5_col2" class="data row5 col2" >736</td>
#     </tr>
#     <tr>
#       <th id="T_fe862_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_fe862_row6_col0" class="data row6 col0" >AkHa00006224</td>
#       <td id="T_fe862_row6_col1" class="data row6 col1" >tap_in_home</td>
#       <td id="T_fe862_row6_col2" class="data row6 col2" >882</td>
#     </tr>
#     <tr>
#       <th id="T_fe862_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_fe862_row7_col0" class="data row7 col0" >AkHa00007224</td>
#       <td id="T_fe862_row7_col1" class="data row7 col1" >tap_in_home</td>
#       <td id="T_fe862_row7_col2" class="data row7 col2" >554</td>
#     </tr>
#     <tr>
#       <th id="T_fe862_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_fe862_row8_col0" class="data row8 col0" >AkHa00008224</td>
#       <td id="T_fe862_row8_col1" class="data row8 col1" >well</td>
#       <td id="T_fe862_row8_col2" class="data row8 col2" >398</td>
#     </tr>
#     <tr>
#       <th id="T_fe862_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_fe862_row9_col0" class="data row9 col0" >AkHa00009224</td>
#       <td id="T_fe862_row9_col1" class="data row9 col1" >well</td>
#       <td id="T_fe862_row9_col2" class="data row9 col2" >346</td>
#     </tr>
#   </tbody>
# </table>
# First 10 rows from table: well_pollution
# <style type="text/css">
# #T_51fa5 thead th {
#   background-color: lightblue;
#   color: black;
#   font-size: 12pt;
#   text-align: center;
# }
# #T_51fa5_row0_col0, #T_51fa5_row0_col1, #T_51fa5_row0_col2, #T_51fa5_row0_col3, #T_51fa5_row0_col4, #T_51fa5_row0_col5, #T_51fa5_row1_col0, #T_51fa5_row1_col1, #T_51fa5_row1_col2, #T_51fa5_row1_col3, #T_51fa5_row1_col4, #T_51fa5_row1_col5, #T_51fa5_row2_col0, #T_51fa5_row2_col1, #T_51fa5_row2_col2, #T_51fa5_row2_col3, #T_51fa5_row2_col4, #T_51fa5_row2_col5, #T_51fa5_row3_col0, #T_51fa5_row3_col1, #T_51fa5_row3_col2, #T_51fa5_row3_col3, #T_51fa5_row3_col4, #T_51fa5_row3_col5, #T_51fa5_row4_col0, #T_51fa5_row4_col1, #T_51fa5_row4_col2, #T_51fa5_row4_col3, #T_51fa5_row4_col4, #T_51fa5_row4_col5, #T_51fa5_row5_col0, #T_51fa5_row5_col1, #T_51fa5_row5_col2, #T_51fa5_row5_col3, #T_51fa5_row5_col4, #T_51fa5_row5_col5, #T_51fa5_row6_col0, #T_51fa5_row6_col1, #T_51fa5_row6_col2, #T_51fa5_row6_col3, #T_51fa5_row6_col4, #T_51fa5_row6_col5, #T_51fa5_row7_col0, #T_51fa5_row7_col1, #T_51fa5_row7_col2, #T_51fa5_row7_col3, #T_51fa5_row7_col4, #T_51fa5_row7_col5, #T_51fa5_row8_col0, #T_51fa5_row8_col1, #T_51fa5_row8_col2, #T_51fa5_row8_col3, #T_51fa5_row8_col4, #T_51fa5_row8_col5, #T_51fa5_row9_col0, #T_51fa5_row9_col1, #T_51fa5_row9_col2, #T_51fa5_row9_col3, #T_51fa5_row9_col4, #T_51fa5_row9_col5 {
#   background-color: #f4f4f4;
# }
# </style>
# <table id="T_51fa5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_51fa5_level0_col0" class="col_heading level0 col0" >source_id</th>
#       <th id="T_51fa5_level0_col1" class="col_heading level0 col1" >date</th>
#       <th id="T_51fa5_level0_col2" class="col_heading level0 col2" >description</th>
#       <th id="T_51fa5_level0_col3" class="col_heading level0 col3" >pollutant_ppm</th>
#       <th id="T_51fa5_level0_col4" class="col_heading level0 col4" >biological</th>
#       <th id="T_51fa5_level0_col5" class="col_heading level0 col5" >results</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_51fa5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_51fa5_row0_col0" class="data row0 col0" >KiRu28935224</td>
#       <td id="T_51fa5_row0_col1" class="data row0 col1" >2021-01-04 09:17:00</td>
#       <td id="T_51fa5_row0_col2" class="data row0 col2" >Bacteria: Giardia Lamblia</td>
#       <td id="T_51fa5_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_51fa5_row0_col4" class="data row0 col4" >495.898000</td>
#       <td id="T_51fa5_row0_col5" class="data row0 col5" >Contaminated: Biological</td>
#     </tr>
#     <tr>
#       <th id="T_51fa5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_51fa5_row1_col0" class="data row1 col0" >AkLu01628224</td>
#       <td id="T_51fa5_row1_col1" class="data row1 col1" >2021-01-04 09:53:00</td>
#       <td id="T_51fa5_row1_col2" class="data row1 col2" >Bacteria: E. coli</td>
#       <td id="T_51fa5_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_51fa5_row1_col4" class="data row1 col4" >6.096080</td>
#       <td id="T_51fa5_row1_col5" class="data row1 col5" >Contaminated: Biological</td>
#     </tr>
#     <tr>
#       <th id="T_51fa5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_51fa5_row2_col0" class="data row2 col0" >HaZa21742224</td>
#       <td id="T_51fa5_row2_col1" class="data row2 col1" >2021-01-04 10:37:00</td>
#       <td id="T_51fa5_row2_col2" class="data row2 col2" >Inorganic contaminants: Zinc, Zinc, Lead, Cadmium</td>
#       <td id="T_51fa5_row2_col3" class="data row2 col3" >2.715000</td>
#       <td id="T_51fa5_row2_col4" class="data row2 col4" >0.000000</td>
#       <td id="T_51fa5_row2_col5" class="data row2 col5" >Contaminated: Chemical</td>
#     </tr>
#     <tr>
#       <th id="T_51fa5_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_51fa5_row3_col0" class="data row3 col0" >HaRu19725224</td>
#       <td id="T_51fa5_row3_col1" class="data row3 col1" >2021-01-04 11:04:00</td>
#       <td id="T_51fa5_row3_col2" class="data row3 col2" >Clean</td>
#       <td id="T_51fa5_row3_col3" class="data row3 col3" >0.028859</td>
#       <td id="T_51fa5_row3_col4" class="data row3 col4" >0.000096</td>
#       <td id="T_51fa5_row3_col5" class="data row3 col5" >Clean</td>
#     </tr>
#     <tr>
#       <th id="T_51fa5_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_51fa5_row4_col0" class="data row4 col0" >SoRu35703224</td>
#       <td id="T_51fa5_row4_col1" class="data row4 col1" >2021-01-04 11:29:00</td>
#       <td id="T_51fa5_row4_col2" class="data row4 col2" >Bacteria: E. coli</td>
#       <td id="T_51fa5_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_51fa5_row4_col4" class="data row4 col4" >22.500900</td>
#       <td id="T_51fa5_row4_col5" class="data row4 col5" >Contaminated: Biological</td>
#     </tr>
#     <tr>
#       <th id="T_51fa5_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_51fa5_row5_col0" class="data row5 col0" >AkHa00070224</td>
#       <td id="T_51fa5_row5_col1" class="data row5 col1" >2021-01-04 11:42:00</td>
#       <td id="T_51fa5_row5_col2" class="data row5 col2" >Inorganic contaminants: Cadmium</td>
#       <td id="T_51fa5_row5_col3" class="data row5 col3" >5.467390</td>
#       <td id="T_51fa5_row5_col4" class="data row5 col4" >0.000000</td>
#       <td id="T_51fa5_row5_col5" class="data row5 col5" >Contaminated: Chemical</td>
#     </tr>
#     <tr>
#       <th id="T_51fa5_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_51fa5_row6_col0" class="data row6 col0" >HaSe21346224</td>
#       <td id="T_51fa5_row6_col1" class="data row6 col1" >2021-01-04 11:52:00</td>
#       <td id="T_51fa5_row6_col2" class="data row6 col2" >Clean</td>
#       <td id="T_51fa5_row6_col3" class="data row6 col3" >0.014038</td>
#       <td id="T_51fa5_row6_col4" class="data row6 col4" >0.000090</td>
#       <td id="T_51fa5_row6_col5" class="data row6 col5" >Clean</td>
#     </tr>
#     <tr>
#       <th id="T_51fa5_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_51fa5_row7_col0" class="data row7 col0" >HaYa21468224</td>
#       <td id="T_51fa5_row7_col1" class="data row7 col1" >2021-01-04 12:03:00</td>
#       <td id="T_51fa5_row7_col2" class="data row7 col2" >Inorganic contaminants: Chromium, Barium, Chromium, Lead</td>
#       <td id="T_51fa5_row7_col3" class="data row7 col3" >6.051370</td>
#       <td id="T_51fa5_row7_col4" class="data row7 col4" >0.000000</td>
#       <td id="T_51fa5_row7_col5" class="data row7 col5" >Contaminated: Chemical</td>
#     </tr>
#     <tr>
#       <th id="T_51fa5_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_51fa5_row8_col0" class="data row8 col0" >SoRu36278224</td>
#       <td id="T_51fa5_row8_col1" class="data row8 col1" >2021-01-04 12:24:00</td>
#       <td id="T_51fa5_row8_col2" class="data row8 col2" >Parasite: Cryptosporidium</td>
#       <td id="T_51fa5_row8_col3" class="data row8 col3" >0.000000</td>
#       <td id="T_51fa5_row8_col4" class="data row8 col4" >485.162000</td>
#       <td id="T_51fa5_row8_col5" class="data row8 col5" >Contaminated: Biological</td>
#     </tr>
#     <tr>
#       <th id="T_51fa5_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_51fa5_row9_col0" class="data row9 col0" >AkLu02155224</td>
#       <td id="T_51fa5_row9_col1" class="data row9 col1" >2021-01-04 12:29:00</td>
#       <td id="T_51fa5_row9_col2" class="data row9 col2" >Inorganic contaminants: Selenium, Arsenic</td>
#       <td id="T_51fa5_row9_col3" class="data row9 col3" >7.641060</td>
#       <td id="T_51fa5_row9_col4" class="data row9 col4" >0.000000</td>
#       <td id="T_51fa5_row9_col5" class="data row9 col5" >Contaminated: Chemical</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Dive into Water Sources: Finding Unique Water Source Types

# %%
# Function to color headers with a custom style
def color_header():
    return [{'selector': 'thead th', 'props': [('background-color', 'lightblue'),
                                               ('color', 'black'),
                                               ('font-size', '12pt'),
                                               ('text-align', 'center')]}]

# Function to apply cell formatting for individual DataFrame cells
def highlight_cells(val):
    return 'background-color: #f4f4f4'  # Light grey for cell background

# Query to find all unique water source types
query = "SELECT DISTINCT type_of_water_source FROM water_source;"

# Execute the query and fetch results as a DataFrame
unique_sources_df = execute_query(query)

# Apply custom table styles and display the styled DataFrame
styled_unique_sources = (
    unique_sources_df.style
    .applymap(highlight_cells)  # Apply custom function to highlight cells
    .set_table_styles(color_header())  # Apply custom header style
)

# Display the unique water source types DataFrame with styles
print("Unique water source types:")
display(styled_unique_sources)
# Out:
# Unique water source types:
# <style type="text/css">
# #T_3243e thead th {
#   background-color: lightblue;
#   color: black;
#   font-size: 12pt;
#   text-align: center;
# }
# #T_3243e_row0_col0, #T_3243e_row1_col0, #T_3243e_row2_col0, #T_3243e_row3_col0, #T_3243e_row4_col0 {
#   background-color: #f4f4f4;
# }
# </style>
# <table id="T_3243e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3243e_level0_col0" class="col_heading level0 col0" >type_of_water_source</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3243e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3243e_row0_col0" class="data row0 col0" >tap_in_home</td>
#     </tr>
#     <tr>
#       <th id="T_3243e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3243e_row1_col0" class="data row1 col0" >tap_in_home_broken</td>
#     </tr>
#     <tr>
#       <th id="T_3243e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3243e_row2_col0" class="data row2 col0" >well</td>
#     </tr>
#     <tr>
#       <th id="T_3243e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3243e_row3_col0" class="data row3 col0" >shared_tap</td>
#     </tr>
#     <tr>
#       <th id="T_3243e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3243e_row4_col0" class="data row4 col0" >river</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Unpack Visits to Water Sources: Locations Wheere queue time is over 8 hours

# %%
# Function to color headers with a custom style
def color_header():
    return [{'selector': 'thead th', 'props': [('background-color', 'lightblue'),
                                               ('color', 'black'),
                                               ('font-size', '12pt'),
                                               ('text-align', 'center')]}]

# Function to apply cell formatting for individual DataFrame cells
def highlight_cells(val):
    return 'background-color: #f4f4f4'  # Light grey for cell background

# SQL query to retrieve records from the visits table where time_in_queue > 500 minutes
query = """
SELECT 
    record_id, 
    location_id, 
    source_id, 
    time_of_record, 
    visit_count, 
    time_in_queue, 
    assigned_employee_id
FROM 
    visits
WHERE 
    time_in_queue > 500 LIMIT 10;
"""

# Execute the query and fetch results as a DataFrame
df_long_queue_times = execute_query(query)

# Display the DataFrame with custom styles
styled_df = df_long_queue_times.style.applymap(highlight_cells).set_table_styles(color_header())

# Show the styled DataFrame
print("Records with time_in_queue > 500 minutes (over 8 hours):")
styled_df
# Out:
# Records with time_in_queue > 500 minutes (over 8 hours):
# <style type="text/css">
# #T_29a94 thead th {
#   background-color: lightblue;
#   color: black;
#   font-size: 12pt;
#   text-align: center;
# }
# #T_29a94_row0_col0, #T_29a94_row0_col1, #T_29a94_row0_col2, #T_29a94_row0_col3, #T_29a94_row0_col4, #T_29a94_row0_col5, #T_29a94_row0_col6, #T_29a94_row1_col0, #T_29a94_row1_col1, #T_29a94_row1_col2, #T_29a94_row1_col3, #T_29a94_row1_col4, #T_29a94_row1_col5, #T_29a94_row1_col6, #T_29a94_row2_col0, #T_29a94_row2_col1, #T_29a94_row2_col2, #T_29a94_row2_col3, #T_29a94_row2_col4, #T_29a94_row2_col5, #T_29a94_row2_col6, #T_29a94_row3_col0, #T_29a94_row3_col1, #T_29a94_row3_col2, #T_29a94_row3_col3, #T_29a94_row3_col4, #T_29a94_row3_col5, #T_29a94_row3_col6, #T_29a94_row4_col0, #T_29a94_row4_col1, #T_29a94_row4_col2, #T_29a94_row4_col3, #T_29a94_row4_col4, #T_29a94_row4_col5, #T_29a94_row4_col6, #T_29a94_row5_col0, #T_29a94_row5_col1, #T_29a94_row5_col2, #T_29a94_row5_col3, #T_29a94_row5_col4, #T_29a94_row5_col5, #T_29a94_row5_col6, #T_29a94_row6_col0, #T_29a94_row6_col1, #T_29a94_row6_col2, #T_29a94_row6_col3, #T_29a94_row6_col4, #T_29a94_row6_col5, #T_29a94_row6_col6, #T_29a94_row7_col0, #T_29a94_row7_col1, #T_29a94_row7_col2, #T_29a94_row7_col3, #T_29a94_row7_col4, #T_29a94_row7_col5, #T_29a94_row7_col6, #T_29a94_row8_col0, #T_29a94_row8_col1, #T_29a94_row8_col2, #T_29a94_row8_col3, #T_29a94_row8_col4, #T_29a94_row8_col5, #T_29a94_row8_col6, #T_29a94_row9_col0, #T_29a94_row9_col1, #T_29a94_row9_col2, #T_29a94_row9_col3, #T_29a94_row9_col4, #T_29a94_row9_col5, #T_29a94_row9_col6 {
#   background-color: #f4f4f4;
# }
# </style>
# <table id="T_29a94">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_29a94_level0_col0" class="col_heading level0 col0" >record_id</th>
#       <th id="T_29a94_level0_col1" class="col_heading level0 col1" >location_id</th>
#       <th id="T_29a94_level0_col2" class="col_heading level0 col2" >source_id</th>
#       <th id="T_29a94_level0_col3" class="col_heading level0 col3" >time_of_record</th>
#       <th id="T_29a94_level0_col4" class="col_heading level0 col4" >visit_count</th>
#       <th id="T_29a94_level0_col5" class="col_heading level0 col5" >time_in_queue</th>
#       <th id="T_29a94_level0_col6" class="col_heading level0 col6" >assigned_employee_id</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_29a94_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_29a94_row0_col0" class="data row0 col0" >899</td>
#       <td id="T_29a94_row0_col1" class="data row0 col1" >SoRu35083</td>
#       <td id="T_29a94_row0_col2" class="data row0 col2" >SoRu35083224</td>
#       <td id="T_29a94_row0_col3" class="data row0 col3" >2021-01-16 10:14:00</td>
#       <td id="T_29a94_row0_col4" class="data row0 col4" >6</td>
#       <td id="T_29a94_row0_col5" class="data row0 col5" >515</td>
#       <td id="T_29a94_row0_col6" class="data row0 col6" >28</td>
#     </tr>
#     <tr>
#       <th id="T_29a94_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_29a94_row1_col0" class="data row1 col0" >2304</td>
#       <td id="T_29a94_row1_col1" class="data row1 col1" >SoKo33124</td>
#       <td id="T_29a94_row1_col2" class="data row1 col2" >SoKo33124224</td>
#       <td id="T_29a94_row1_col3" class="data row1 col3" >2021-02-06 07:53:00</td>
#       <td id="T_29a94_row1_col4" class="data row1 col4" >5</td>
#       <td id="T_29a94_row1_col5" class="data row1 col5" >512</td>
#       <td id="T_29a94_row1_col6" class="data row1 col6" >16</td>
#     </tr>
#     <tr>
#       <th id="T_29a94_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_29a94_row2_col0" class="data row2 col0" >2315</td>
#       <td id="T_29a94_row2_col1" class="data row2 col1" >KiRu26095</td>
#       <td id="T_29a94_row2_col2" class="data row2 col2" >KiRu26095224</td>
#       <td id="T_29a94_row2_col3" class="data row2 col3" >2021-02-06 14:32:00</td>
#       <td id="T_29a94_row2_col4" class="data row2 col4" >3</td>
#       <td id="T_29a94_row2_col5" class="data row2 col5" >529</td>
#       <td id="T_29a94_row2_col6" class="data row2 col6" >8</td>
#     </tr>
#     <tr>
#       <th id="T_29a94_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_29a94_row3_col0" class="data row3 col0" >3206</td>
#       <td id="T_29a94_row3_col1" class="data row3 col1" >SoRu38776</td>
#       <td id="T_29a94_row3_col2" class="data row3 col2" >SoRu38776224</td>
#       <td id="T_29a94_row3_col3" class="data row3 col3" >2021-02-20 15:03:00</td>
#       <td id="T_29a94_row3_col4" class="data row3 col4" >5</td>
#       <td id="T_29a94_row3_col5" class="data row3 col5" >509</td>
#       <td id="T_29a94_row3_col6" class="data row3 col6" >46</td>
#     </tr>
#     <tr>
#       <th id="T_29a94_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_29a94_row4_col0" class="data row4 col0" >3701</td>
#       <td id="T_29a94_row4_col1" class="data row4 col1" >HaRu19601</td>
#       <td id="T_29a94_row4_col2" class="data row4 col2" >HaRu19601224</td>
#       <td id="T_29a94_row4_col3" class="data row4 col3" >2021-02-27 12:53:00</td>
#       <td id="T_29a94_row4_col4" class="data row4 col4" >3</td>
#       <td id="T_29a94_row4_col5" class="data row4 col5" >504</td>
#       <td id="T_29a94_row4_col6" class="data row4 col6" >0</td>
#     </tr>
#     <tr>
#       <th id="T_29a94_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_29a94_row5_col0" class="data row5 col0" >4154</td>
#       <td id="T_29a94_row5_col1" class="data row5 col1" >SoRu38869</td>
#       <td id="T_29a94_row5_col2" class="data row5 col2" >SoRu38869224</td>
#       <td id="T_29a94_row5_col3" class="data row5 col3" >2021-03-06 10:44:00</td>
#       <td id="T_29a94_row5_col4" class="data row5 col4" >2</td>
#       <td id="T_29a94_row5_col5" class="data row5 col5" >533</td>
#       <td id="T_29a94_row5_col6" class="data row5 col6" >24</td>
#     </tr>
#     <tr>
#       <th id="T_29a94_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_29a94_row6_col0" class="data row6 col0" >5483</td>
#       <td id="T_29a94_row6_col1" class="data row6 col1" >AmRu14089</td>
#       <td id="T_29a94_row6_col2" class="data row6 col2" >AmRu14089224</td>
#       <td id="T_29a94_row6_col3" class="data row6 col3" >2021-03-27 18:15:00</td>
#       <td id="T_29a94_row6_col4" class="data row6 col4" >4</td>
#       <td id="T_29a94_row6_col5" class="data row6 col5" >509</td>
#       <td id="T_29a94_row6_col6" class="data row6 col6" >12</td>
#     </tr>
#     <tr>
#       <th id="T_29a94_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_29a94_row7_col0" class="data row7 col0" >9177</td>
#       <td id="T_29a94_row7_col1" class="data row7 col1" >SoRu37635</td>
#       <td id="T_29a94_row7_col2" class="data row7 col2" >SoRu37635224</td>
#       <td id="T_29a94_row7_col3" class="data row7 col3" >2021-05-22 18:48:00</td>
#       <td id="T_29a94_row7_col4" class="data row7 col4" >2</td>
#       <td id="T_29a94_row7_col5" class="data row7 col5" >515</td>
#       <td id="T_29a94_row7_col6" class="data row7 col6" >1</td>
#     </tr>
#     <tr>
#       <th id="T_29a94_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_29a94_row8_col0" class="data row8 col0" >9648</td>
#       <td id="T_29a94_row8_col1" class="data row8 col1" >SoRu36096</td>
#       <td id="T_29a94_row8_col2" class="data row8 col2" >SoRu36096224</td>
#       <td id="T_29a94_row8_col3" class="data row8 col3" >2021-05-29 11:24:00</td>
#       <td id="T_29a94_row8_col4" class="data row8 col4" >2</td>
#       <td id="T_29a94_row8_col5" class="data row8 col5" >533</td>
#       <td id="T_29a94_row8_col6" class="data row8 col6" >3</td>
#     </tr>
#     <tr>
#       <th id="T_29a94_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_29a94_row9_col0" class="data row9 col0" >11631</td>
#       <td id="T_29a94_row9_col1" class="data row9 col1" >AkKi00881</td>
#       <td id="T_29a94_row9_col2" class="data row9 col2" >AkKi00881224</td>
#       <td id="T_29a94_row9_col3" class="data row9 col3" >2021-06-26 06:15:00</td>
#       <td id="T_29a94_row9_col4" class="data row9 col4" >6</td>

# %% [markdown]
# ## Assess the quality of water sources:

# %%
# Function to color headers with a custom style
def color_header():
    return [{'selector': 'thead th', 'props': [('background-color', 'lightblue'),
                                               ('color', 'black'),
                                               ('font-size', '12pt'),
                                               ('text-align', 'center')]}]

# Function to apply cell formatting for individual DataFrame cells
def highlight_cells(val):
    return 'background-color: #f4f4f4'  # Light grey for cell background

# SQL query to find records with subjective_quality_score of 10 for home taps 
# and where the source was visited more than once
query = """
SELECT v.record_id, v.location_id, v.source_id, v.time_of_record, 
       wq.subjective_quality_score, wq.visit_count, v.time_in_queue, 
       v.assigned_employee_id
FROM visits v
JOIN water_quality wq ON v.record_id = wq.record_id
WHERE wq.subjective_quality_score = 10
  AND wq.visit_count > 1 
LIMIT 10;  -- Looking for records with visit count greater than 1
"""

# Execute the query and fetch results as a DataFrame
try:
    high_quality_home_taps = execute_query(query)

    # Display the DataFrame with custom styles
    styled_df = high_quality_home_taps.style.applymap(highlight_cells).set_table_styles(color_header())

    # Show the styled DataFrame
    print("Records where subjective_quality_score is 10 and visited more than once:")
    display(styled_df)  # Use display() to render the styled DataFrame properly in a Jupyter Notebook

except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Records where subjective_quality_score is 10 and visited more than once:
# <style type="text/css">
# #T_32595 thead th {
#   background-color: lightblue;
#   color: black;
#   font-size: 12pt;
#   text-align: center;
# }
# #T_32595_row0_col0, #T_32595_row0_col1, #T_32595_row0_col2, #T_32595_row0_col3, #T_32595_row0_col4, #T_32595_row0_col5, #T_32595_row0_col6, #T_32595_row0_col7, #T_32595_row1_col0, #T_32595_row1_col1, #T_32595_row1_col2, #T_32595_row1_col3, #T_32595_row1_col4, #T_32595_row1_col5, #T_32595_row1_col6, #T_32595_row1_col7, #T_32595_row2_col0, #T_32595_row2_col1, #T_32595_row2_col2, #T_32595_row2_col3, #T_32595_row2_col4, #T_32595_row2_col5, #T_32595_row2_col6, #T_32595_row2_col7, #T_32595_row3_col0, #T_32595_row3_col1, #T_32595_row3_col2, #T_32595_row3_col3, #T_32595_row3_col4, #T_32595_row3_col5, #T_32595_row3_col6, #T_32595_row3_col7, #T_32595_row4_col0, #T_32595_row4_col1, #T_32595_row4_col2, #T_32595_row4_col3, #T_32595_row4_col4, #T_32595_row4_col5, #T_32595_row4_col6, #T_32595_row4_col7, #T_32595_row5_col0, #T_32595_row5_col1, #T_32595_row5_col2, #T_32595_row5_col3, #T_32595_row5_col4, #T_32595_row5_col5, #T_32595_row5_col6, #T_32595_row5_col7, #T_32595_row6_col0, #T_32595_row6_col1, #T_32595_row6_col2, #T_32595_row6_col3, #T_32595_row6_col4, #T_32595_row6_col5, #T_32595_row6_col6, #T_32595_row6_col7, #T_32595_row7_col0, #T_32595_row7_col1, #T_32595_row7_col2, #T_32595_row7_col3, #T_32595_row7_col4, #T_32595_row7_col5, #T_32595_row7_col6, #T_32595_row7_col7, #T_32595_row8_col0, #T_32595_row8_col1, #T_32595_row8_col2, #T_32595_row8_col3, #T_32595_row8_col4, #T_32595_row8_col5, #T_32595_row8_col6, #T_32595_row8_col7, #T_32595_row9_col0, #T_32595_row9_col1, #T_32595_row9_col2, #T_32595_row9_col3, #T_32595_row9_col4, #T_32595_row9_col5, #T_32595_row9_col6, #T_32595_row9_col7 {
#   background-color: #f4f4f4;
# }
# </style>
# <table id="T_32595">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_32595_level0_col0" class="col_heading level0 col0" >record_id</th>
#       <th id="T_32595_level0_col1" class="col_heading level0 col1" >location_id</th>
#       <th id="T_32595_level0_col2" class="col_heading level0 col2" >source_id</th>
#       <th id="T_32595_level0_col3" class="col_heading level0 col3" >time_of_record</th>
#       <th id="T_32595_level0_col4" class="col_heading level0 col4" >subjective_quality_score</th>
#       <th id="T_32595_level0_col5" class="col_heading level0 col5" >visit_count</th>
#       <th id="T_32595_level0_col6" class="col_heading level0 col6" >time_in_queue</th>
#       <th id="T_32595_level0_col7" class="col_heading level0 col7" >assigned_employee_id</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_32595_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_32595_row0_col0" class="data row0 col0" >59</td>
#       <td id="T_32595_row0_col1" class="data row0 col1" >SoRu35008</td>
#       <td id="T_32595_row0_col2" class="data row0 col2" >SoRu35008224</td>
#       <td id="T_32595_row0_col3" class="data row0 col3" >2021-01-02 07:27:00</td>
#       <td id="T_32595_row0_col4" class="data row0 col4" >10</td>
#       <td id="T_32595_row0_col5" class="data row0 col5" >2</td>
#       <td id="T_32595_row0_col6" class="data row0 col6" >248</td>
#       <td id="T_32595_row0_col7" class="data row0 col7" >1</td>
#     </tr>
#     <tr>
#       <th id="T_32595_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_32595_row1_col0" class="data row1 col0" >67</td>
#       <td id="T_32595_row1_col1" class="data row1 col1" >SoRu35008</td>
#       <td id="T_32595_row1_col2" class="data row1 col2" >SoRu35008224</td>
#       <td id="T_32595_row1_col3" class="data row1 col3" >2021-01-03 14:31:00</td>
#       <td id="T_32595_row1_col4" class="data row1 col4" >10</td>
#       <td id="T_32595_row1_col5" class="data row1 col5" >3</td>
#       <td id="T_32595_row1_col6" class="data row1 col6" >104</td>
#       <td id="T_32595_row1_col7" class="data row1 col7" >1</td>
#     </tr>
#     <tr>
#       <th id="T_32595_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_32595_row2_col0" class="data row2 col0" >85</td>
#       <td id="T_32595_row2_col1" class="data row2 col1" >SoRu35008</td>
#       <td id="T_32595_row2_col2" class="data row2 col2" >SoRu35008224</td>
#       <td id="T_32595_row2_col3" class="data row2 col3" >2021-01-04 12:12:00</td>
#       <td id="T_32595_row2_col4" class="data row2 col4" >10</td>
#       <td id="T_32595_row2_col5" class="data row2 col5" >4</td>
#       <td id="T_32595_row2_col6" class="data row2 col6" >165</td>
#       <td id="T_32595_row2_col7" class="data row2 col7" >1</td>
#     </tr>
#     <tr>
#       <th id="T_32595_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_32595_row3_col0" class="data row3 col0" >128</td>
#       <td id="T_32595_row3_col1" class="data row3 col1" >SoRu35008</td>
#       <td id="T_32595_row3_col2" class="data row3 col2" >SoRu35008224</td>
#       <td id="T_32595_row3_col3" class="data row3 col3" >2021-01-05 08:13:00</td>
#       <td id="T_32595_row3_col4" class="data row3 col4" >10</td>
#       <td id="T_32595_row3_col5" class="data row3 col5" >5</td>
#       <td id="T_32595_row3_col6" class="data row3 col6" >213</td>
#       <td id="T_32595_row3_col7" class="data row3 col7" >1</td>
#     </tr>
#     <tr>
#       <th id="T_32595_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_32595_row4_col0" class="data row4 col0" >137</td>
#       <td id="T_32595_row4_col1" class="data row4 col1" >KiMr25211</td>
#       <td id="T_32595_row4_col2" class="data row4 col2" >KiMr25211224</td>
#       <td id="T_32595_row4_col3" class="data row4 col3" >2021-01-05 09:47:00</td>
#       <td id="T_32595_row4_col4" class="data row4 col4" >10</td>
#       <td id="T_32595_row4_col5" class="data row4 col5" >2</td>
#       <td id="T_32595_row4_col6" class="data row4 col6" >64</td>
#       <td id="T_32595_row4_col7" class="data row4 col7" >3</td>
#     </tr>
#     <tr>
#       <th id="T_32595_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_32595_row5_col0" class="data row5 col0" >232</td>
#       <td id="T_32595_row5_col1" class="data row5 col1" >KiMr25211</td>
#       <td id="T_32595_row5_col2" class="data row5 col2" >KiMr25211224</td>
#       <td id="T_32595_row5_col3" class="data row5 col3" >2021-01-06 12:34:00</td>
#       <td id="T_32595_row5_col4" class="data row5 col4" >10</td>
#       <td id="T_32595_row5_col5" class="data row5 col5" >3</td>
#       <td id="T_32595_row5_col6" class="data row5 col6" >110</td>
#       <td id="T_32595_row5_col7" class="data row5 col7" >3</td>
#     </tr>
#     <tr>
#       <th id="T_32595_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_32595_row6_col0" class="data row6 col0" >263</td>
#       <td id="T_32595_row6_col1" class="data row6 col1" >SoRu35008</td>
#       <td id="T_32595_row6_col2" class="data row6 col2" >SoRu35008224</td>
#       <td id="T_32595_row6_col3" class="data row6 col3" >2021-01-06 15:48:00</td>
#       <td id="T_32595_row6_col4" class="data row6 col4" >10</td>
#       <td id="T_32595_row6_col5" class="data row6 col5" >6</td>
#       <td id="T_32595_row6_col6" class="data row6 col6" >93</td>
#       <td id="T_32595_row6_col7" class="data row6 col7" >1</td>
#     </tr>
#     <tr>
#       <th id="T_32595_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_32595_row7_col0" class="data row7 col0" >269</td>
#       <td id="T_32595_row7_col1" class="data row7 col1" >AkRu08557</td>
#       <td id="T_32595_row7_col2" class="data row7 col2" >AkRu08557224</td>
#       <td id="T_32595_row7_col3" class="data row7 col3" >2021-01-06 18:55:00</td>
#       <td id="T_32595_row7_col4" class="data row7 col4" >10</td>
#       <td id="T_32595_row7_col5" class="data row7 col5" >2</td>
#       <td id="T_32595_row7_col6" class="data row7 col6" >48</td>
#       <td id="T_32595_row7_col7" class="data row7 col7" >1</td>
#     </tr>
#     <tr>
#       <th id="T_32595_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_32595_row8_col0" class="data row8 col0" >271</td>
#       <td id="T_32595_row8_col1" class="data row8 col1" >AkRu08557</td>
#       <

# %% [markdown]
# ## Investigate pollution issues:

# %%
# Function to color headers with a custom style
def color_header():
    return [{'selector': 'thead th', 'props': [('background-color', 'lightblue'),
                                               ('color', 'black'),
                                               ('font-size', '12pt'),
                                               ('text-align', 'center')]}]

# Function to apply cell formatting for individual DataFrame cells
def highlight_cells(val):
    return 'background-color: #f4f4f4'  # Light grey for cell background

# Define the query to retrieve pollution data
query = """
SELECT source_id, date, description, pollutant_ppm, biological, results
FROM well_pollution
LIMIT 10;
"""

# Execute the query and fetch results
try:
    pollution_data = execute_query(query)

    # Display the DataFrame with custom styles
    styled_df = pollution_data.style.applymap(highlight_cells).set_table_styles(color_header())

    # Show the styled DataFrame
    print("First few rows of pollution data:")
    display(styled_df)  # Use display() to render the styled DataFrame properly in a Jupyter Notebook

except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# First few rows of pollution data:
# <style type="text/css">
# #T_d2a1a thead th {
#   background-color: lightblue;
#   color: black;
#   font-size: 12pt;
#   text-align: center;
# }
# #T_d2a1a_row0_col0, #T_d2a1a_row0_col1, #T_d2a1a_row0_col2, #T_d2a1a_row0_col3, #T_d2a1a_row0_col4, #T_d2a1a_row0_col5, #T_d2a1a_row1_col0, #T_d2a1a_row1_col1, #T_d2a1a_row1_col2, #T_d2a1a_row1_col3, #T_d2a1a_row1_col4, #T_d2a1a_row1_col5, #T_d2a1a_row2_col0, #T_d2a1a_row2_col1, #T_d2a1a_row2_col2, #T_d2a1a_row2_col3, #T_d2a1a_row2_col4, #T_d2a1a_row2_col5, #T_d2a1a_row3_col0, #T_d2a1a_row3_col1, #T_d2a1a_row3_col2, #T_d2a1a_row3_col3, #T_d2a1a_row3_col4, #T_d2a1a_row3_col5, #T_d2a1a_row4_col0, #T_d2a1a_row4_col1, #T_d2a1a_row4_col2, #T_d2a1a_row4_col3, #T_d2a1a_row4_col4, #T_d2a1a_row4_col5, #T_d2a1a_row5_col0, #T_d2a1a_row5_col1, #T_d2a1a_row5_col2, #T_d2a1a_row5_col3, #T_d2a1a_row5_col4, #T_d2a1a_row5_col5, #T_d2a1a_row6_col0, #T_d2a1a_row6_col1, #T_d2a1a_row6_col2, #T_d2a1a_row6_col3, #T_d2a1a_row6_col4, #T_d2a1a_row6_col5, #T_d2a1a_row7_col0, #T_d2a1a_row7_col1, #T_d2a1a_row7_col2, #T_d2a1a_row7_col3, #T_d2a1a_row7_col4, #T_d2a1a_row7_col5, #T_d2a1a_row8_col0, #T_d2a1a_row8_col1, #T_d2a1a_row8_col2, #T_d2a1a_row8_col3, #T_d2a1a_row8_col4, #T_d2a1a_row8_col5, #T_d2a1a_row9_col0, #T_d2a1a_row9_col1, #T_d2a1a_row9_col2, #T_d2a1a_row9_col3, #T_d2a1a_row9_col4, #T_d2a1a_row9_col5 {
#   background-color: #f4f4f4;
# }
# </style>
# <table id="T_d2a1a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d2a1a_level0_col0" class="col_heading level0 col0" >source_id</th>
#       <th id="T_d2a1a_level0_col1" class="col_heading level0 col1" >date</th>
#       <th id="T_d2a1a_level0_col2" class="col_heading level0 col2" >description</th>
#       <th id="T_d2a1a_level0_col3" class="col_heading level0 col3" >pollutant_ppm</th>
#       <th id="T_d2a1a_level0_col4" class="col_heading level0 col4" >biological</th>
#       <th id="T_d2a1a_level0_col5" class="col_heading level0 col5" >results</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d2a1a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d2a1a_row0_col0" class="data row0 col0" >KiRu28935224</td>
#       <td id="T_d2a1a_row0_col1" class="data row0 col1" >2021-01-04 09:17:00</td>
#       <td id="T_d2a1a_row0_col2" class="data row0 col2" >Bacteria: Giardia Lamblia</td>
#       <td id="T_d2a1a_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_d2a1a_row0_col4" class="data row0 col4" >495.898000</td>
#       <td id="T_d2a1a_row0_col5" class="data row0 col5" >Contaminated: Biological</td>
#     </tr>
#     <tr>
#       <th id="T_d2a1a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d2a1a_row1_col0" class="data row1 col0" >AkLu01628224</td>
#       <td id="T_d2a1a_row1_col1" class="data row1 col1" >2021-01-04 09:53:00</td>
#       <td id="T_d2a1a_row1_col2" class="data row1 col2" >Bacteria: E. coli</td>
#       <td id="T_d2a1a_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_d2a1a_row1_col4" class="data row1 col4" >6.096080</td>
#       <td id="T_d2a1a_row1_col5" class="data row1 col5" >Contaminated: Biological</td>
#     </tr>
#     <tr>
#       <th id="T_d2a1a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d2a1a_row2_col0" class="data row2 col0" >HaZa21742224</td>
#       <td id="T_d2a1a_row2_col1" class="data row2 col1" >2021-01-04 10:37:00</td>
#       <td id="T_d2a1a_row2_col2" class="data row2 col2" >Inorganic contaminants: Zinc, Zinc, Lead, Cadmium</td>
#       <td id="T_d2a1a_row2_col3" class="data row2 col3" >2.715000</td>
#       <td id="T_d2a1a_row2_col4" class="data row2 col4" >0.000000</td>
#       <td id="T_d2a1a_row2_col5" class="data row2 col5" >Contaminated: Chemical</td>
#     </tr>
#     <tr>
#       <th id="T_d2a1a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d2a1a_row3_col0" class="data row3 col0" >HaRu19725224</td>
#       <td id="T_d2a1a_row3_col1" class="data row3 col1" >2021-01-04 11:04:00</td>
#       <td id="T_d2a1a_row3_col2" class="data row3 col2" >Clean</td>
#       <td id="T_d2a1a_row3_col3" class="data row3 col3" >0.028859</td>
#       <td id="T_d2a1a_row3_col4" class="data row3 col4" >0.000096</td>
#       <td id="T_d2a1a_row3_col5" class="data row3 col5" >Clean</td>
#     </tr>
#     <tr>
#       <th id="T_d2a1a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d2a1a_row4_col0" class="data row4 col0" >SoRu35703224</td>
#       <td id="T_d2a1a_row4_col1" class="data row4 col1" >2021-01-04 11:29:00</td>
#       <td id="T_d2a1a_row4_col2" class="data row4 col2" >Bacteria: E. coli</td>
#       <td id="T_d2a1a_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_d2a1a_row4_col4" class="data row4 col4" >22.500900</td>
#       <td id="T_d2a1a_row4_col5" class="data row4 col5" >Contaminated: Biological</td>
#     </tr>
#     <tr>
#       <th id="T_d2a1a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d2a1a_row5_col0" class="data row5 col0" >AkHa00070224</td>
#       <td id="T_d2a1a_row5_col1" class="data row5 col1" >2021-01-04 11:42:00</td>
#       <td id="T_d2a1a_row5_col2" class="data row5 col2" >Inorganic contaminants: Cadmium</td>
#       <td id="T_d2a1a_row5_col3" class="data row5 col3" >5.467390</td>
#       <td id="T_d2a1a_row5_col4" class="data row5 col4" >0.000000</td>
#       <td id="T_d2a1a_row5_col5" class="data row5 col5" >Contaminated: Chemical</td>
#     </tr>
#     <tr>
#       <th id="T_d2a1a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d2a1a_row6_col0" class="data row6 col0" >HaSe21346224</td>
#       <td id="T_d2a1a_row6_col1" class="data row6 col1" >2021-01-04 11:52:00</td>
#       <td id="T_d2a1a_row6_col2" class="data row6 col2" >Clean</td>
#       <td id="T_d2a1a_row6_col3" class="data row6 col3" >0.014038</td>
#       <td id="T_d2a1a_row6_col4" class="data row6 col4" >0.000090</td>
#       <td id="T_d2a1a_row6_col5" class="data row6 col5" >Clean</td>
#     </tr>
#     <tr>
#       <th id="T_d2a1a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d2a1a_row7_col0" class="data row7 col0" >HaYa21468224</td>
#       <td id="T_d2a1a_row7_col1" class="data row7 col1" >2021-01-04 12:03:00</td>
#       <td id="T_d2a1a_row7_col2" class="data row7 col2" >Inorganic contaminants: Chromium, Barium, Chromium, Lead</td>
#       <td id="T_d2a1a_row7_col3" class="data row7 col3" >6.051370</td>
#       <td id="T_d2a1a_row7_col4" class="data row7 col4" >0.000000</td>
#       <td id="T_d2a1a_row7_col5" class="data row7 col5" >Contaminated: Chemical</td>
#     </tr>
#     <tr>
#       <th id="T_d2a1a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_d2a1a_row8_col0" class="data row8 col0" >SoRu36278224</td>
#       <td id="T_d2a1a_row8_col1" class="data row8 col1" >2021-01-04 12:24:00</td>
#       <td id="T_d2a1a_row8_col2" class="data row8 col2" >Parasite: Cryptosporidium</td>
#       <td id="T_d2a1a_row8_col3" class="data row8 col3" >0.000000</td>
#       <td id="T_d2a1a_row8_col4" class="data row8 col4" >485.162000</td>
#       <td id="T_d2a1a_row8_col5" class="data row8 col5" >Contaminated: Biological</td>
#     </tr>
#     <tr>
#       <th id="T_d2a1a_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_d2a1a_row9_col0" class="data row9 col0" >AkLu02155224</td>
#       <td id="T_d2a1a_row9_col1" class="data row9 col1" >2021-01-04 12:29:00</td>
#       <td id="T_d2a1a_row9_col2" class="data row9 col2" >Inorganic contaminants: Selenium, Arsenic</td>
#       <td id="T_d2a1a_row9_col3" class="data row9 col3" >7.641060</td>
#       <td id="T_d2a1a_row9_col4" class="data row9 col4" >0.000000</td>
#       <td id="T_d2a1a_row9_col5" class="data row9 col5" >Contaminated: Chemical</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### a query that checks if the results is Clean but the biological column is > 0.01.

# %%
# Function to color headers with a custom style
def color_header():
    return [{'selector': 'thead th', 'props': [('background-color', 'lightblue'),
                                               ('color', 'black'),
                                               ('font-size', '12pt'),
                                               ('text-align', 'center')]}]

# Function to apply cell formatting for individual DataFrame cells
def highlight_cells(val):
    return 'background-color: #f4f4f4'  # Light grey for cell background

# Query to find records with Clean descriptions and biological > 0.01
query = """
SELECT *
FROM well_pollution
WHERE description LIKE 'Clean%' AND biological > 0.01 LIMIT 10;
"""

# Execute the query and get the results
results_df = execute_query(query)

# Apply styling to the DataFrame for display (if using Jupyter Notebook)
styled_df = results_df.style.applymap(highlight_cells).set_table_styles(color_header())
styled_df  # Display the styled DataFrame
# Out:
# <style type="text/css">
# #T_522a5 thead th {
#   background-color: lightblue;
#   color: black;
#   font-size: 12pt;
#   text-align: center;
# }
# #T_522a5_row0_col0, #T_522a5_row0_col1, #T_522a5_row0_col2, #T_522a5_row0_col3, #T_522a5_row0_col4, #T_522a5_row0_col5, #T_522a5_row1_col0, #T_522a5_row1_col1, #T_522a5_row1_col2, #T_522a5_row1_col3, #T_522a5_row1_col4, #T_522a5_row1_col5, #T_522a5_row2_col0, #T_522a5_row2_col1, #T_522a5_row2_col2, #T_522a5_row2_col3, #T_522a5_row2_col4, #T_522a5_row2_col5, #T_522a5_row3_col0, #T_522a5_row3_col1, #T_522a5_row3_col2, #T_522a5_row3_col3, #T_522a5_row3_col4, #T_522a5_row3_col5, #T_522a5_row4_col0, #T_522a5_row4_col1, #T_522a5_row4_col2, #T_522a5_row4_col3, #T_522a5_row4_col4, #T_522a5_row4_col5, #T_522a5_row5_col0, #T_522a5_row5_col1, #T_522a5_row5_col2, #T_522a5_row5_col3, #T_522a5_row5_col4, #T_522a5_row5_col5, #T_522a5_row6_col0, #T_522a5_row6_col1, #T_522a5_row6_col2, #T_522a5_row6_col3, #T_522a5_row6_col4, #T_522a5_row6_col5, #T_522a5_row7_col0, #T_522a5_row7_col1, #T_522a5_row7_col2, #T_522a5_row7_col3, #T_522a5_row7_col4, #T_522a5_row7_col5, #T_522a5_row8_col0, #T_522a5_row8_col1, #T_522a5_row8_col2, #T_522a5_row8_col3, #T_522a5_row8_col4, #T_522a5_row8_col5, #T_522a5_row9_col0, #T_522a5_row9_col1, #T_522a5_row9_col2, #T_522a5_row9_col3, #T_522a5_row9_col4, #T_522a5_row9_col5 {
#   background-color: #f4f4f4;
# }
# </style>
# <table id="T_522a5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_522a5_level0_col0" class="col_heading level0 col0" >source_id</th>
#       <th id="T_522a5_level0_col1" class="col_heading level0 col1" >date</th>
#       <th id="T_522a5_level0_col2" class="col_heading level0 col2" >description</th>
#       <th id="T_522a5_level0_col3" class="col_heading level0 col3" >pollutant_ppm</th>
#       <th id="T_522a5_level0_col4" class="col_heading level0 col4" >biological</th>
#       <th id="T_522a5_level0_col5" class="col_heading level0 col5" >results</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_522a5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_522a5_row0_col0" class="data row0 col0" >AkRu06489224</td>
#       <td id="T_522a5_row0_col1" class="data row0 col1" >2021-01-10 09:44:00</td>
#       <td id="T_522a5_row0_col2" class="data row0 col2" >Clean Bacteria: Giardia Lamblia</td>
#       <td id="T_522a5_row0_col3" class="data row0 col3" >0.089790</td>
#       <td id="T_522a5_row0_col4" class="data row0 col4" >38.467000</td>
#       <td id="T_522a5_row0_col5" class="data row0 col5" >Clean</td>
#     </tr>
#     <tr>
#       <th id="T_522a5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_522a5_row1_col0" class="data row1 col0" >KiRu25473224</td>
#       <td id="T_522a5_row1_col1" class="data row1 col1" >2021-02-07 15:51:00</td>
#       <td id="T_522a5_row1_col2" class="data row1 col2" >Clean Bacteria: Giardia Lamblia</td>
#       <td id="T_522a5_row1_col3" class="data row1 col3" >0.063009</td>
#       <td id="T_522a5_row1_col4" class="data row1 col4" >24.453600</td>
#       <td id="T_522a5_row1_col5" class="data row1 col5" >Clean</td>
#     </tr>
#     <tr>
#       <th id="T_522a5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_522a5_row2_col0" class="data row2 col0" >HaRu17401224</td>
#       <td id="T_522a5_row2_col1" class="data row2 col1" >2021-03-01 13:44:00</td>
#       <td id="T_522a5_row2_col2" class="data row2 col2" >Clean Bacteria: Giardia Lamblia</td>
#       <td id="T_522a5_row2_col3" class="data row2 col3" >0.064921</td>
#       <td id="T_522a5_row2_col4" class="data row2 col4" >25.812900</td>
#       <td id="T_522a5_row2_col5" class="data row2 col5" >Clean</td>
#     </tr>
#     <tr>
#       <th id="T_522a5_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_522a5_row3_col0" class="data row3 col0" >AkRu07137224</td>
#       <td id="T_522a5_row3_col1" class="data row3 col1" >2021-03-04 13:41:00</td>
#       <td id="T_522a5_row3_col2" class="data row3 col2" >Clean Bacteria: Giardia Lamblia</td>
#       <td id="T_522a5_row3_col3" class="data row3 col3" >0.065684</td>
#       <td id="T_522a5_row3_col4" class="data row3 col4" >18.297800</td>
#       <td id="T_522a5_row3_col5" class="data row3 col5" >Clean</td>
#     </tr>
#     <tr>
#       <th id="T_522a5_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_522a5_row4_col0" class="data row4 col0" >KiRu27205224</td>
#       <td id="T_522a5_row4_col1" class="data row4 col1" >2021-03-13 14:17:00</td>
#       <td id="T_522a5_row4_col2" class="data row4 col2" >Clean Bacteria: Giardia Lamblia</td>
#       <td id="T_522a5_row4_col3" class="data row4 col3" >0.041802</td>
#       <td id="T_522a5_row4_col4" class="data row4 col4" >49.428100</td>
#       <td id="T_522a5_row4_col5" class="data row4 col5" >Clean</td>
#     </tr>
#     <tr>
#       <th id="T_522a5_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_522a5_row5_col0" class="data row5 col0" >AkHa00514224</td>
#       <td id="T_522a5_row5_col1" class="data row5 col1" >2021-04-11 12:11:00</td>
#       <td id="T_522a5_row5_col2" class="data row5 col2" >Clean Bacteria: Giardia Lamblia</td>
#       <td id="T_522a5_row5_col3" class="data row5 col3" >0.030540</td>
#       <td id="T_522a5_row5_col4" class="data row5 col4" >22.025500</td>
#       <td id="T_522a5_row5_col5" class="data row5 col5" >Clean</td>
#     </tr>
#     <tr>
#       <th id="T_522a5_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_522a5_row6_col0" class="data row6 col0" >AmAm09776224</td>
#       <td id="T_522a5_row6_col1" class="data row6 col1" >2021-05-23 11:28:00</td>
#       <td id="T_522a5_row6_col2" class="data row6 col2" >Clean Bacteria: Giardia Lamblia</td>
#       <td id="T_522a5_row6_col3" class="data row6 col3" >0.096382</td>
#       <td id="T_522a5_row6_col4" class="data row6 col4" >13.657400</td>
#       <td id="T_522a5_row6_col5" class="data row6 col5" >Clean</td>
#     </tr>
#     <tr>
#       <th id="T_522a5_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_522a5_row7_col0" class="data row7 col0" >SoIl32894224</td>
#       <td id="T_522a5_row7_col1" class="data row7 col1" >2021-07-11 11:37:00</td>
#       <td id="T_522a5_row7_col2" class="data row7 col2" >Clean Bacteria: Giardia Lamblia</td>
#       <td id="T_522a5_row7_col3" class="data row7 col3" >0.071241</td>
#       <td id="T_522a5_row7_col4" class="data row7 col4" >5.449570</td>
#       <td id="T_522a5_row7_col5" class="data row7 col5" >Clean</td>
#     </tr>
#     <tr>
#       <th id="T_522a5_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_522a5_row8_col0" class="data row8 col0" >AkRu07366224</td>
#       <td id="T_522a5_row8_col1" class="data row8 col1" >2021-07-23 11:19:00</td>
#       <td id="T_522a5_row8_col2" class="data row8 col2" >Clean Bacteria: Giardia Lamblia</td>
#       <td id="T_522a5_row8_col3" class="data row8 col3" >0.096946</td>
#       <td id="T_522a5_row8_col4" class="data row8 col4" >26.030800</td>
#       <td id="T_522a5_row8_col5" class="data row8 col5" >Clean</td>
#     </tr>
#     <tr>
#       <th id="T_522a5_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_522a5_row9_col0" class="data row9 col0" >KiHa23443224</td>
#       <td id="T_522a5_row9_col1" class="data row9 col1" >2021-09-05 12:34:00</td>
#       <td id="T_522a5_row9_col2" class="data row9 col2" >Clean Bacteria: Giardia Lamblia</td>
#       <td id="T_522a5_row9_col3" class="data row9 col3" >0.082800</td>
#       <td id="T_522a5_row9_col4" class="data row9 col4" >13.716200</td>
#       <td id="T_522a5_row9_col5" class="data row9 col5" >Clean</td>
#     </tr>
#   </tbody>
# </table>
